# %%
import os
import re
from rdkit import Chem
from rdkit.Chem.rdMolDescriptors import CalcMolFormula
from splash import Spectrum, SpectrumType, Splash
import time
import json

atom = {"H":1.008, "C": 12.011, "O":15.999, "N": 14.007, "P":30.976, "S": 32.065}  
inputdir = "/Users/donghanli/Documents/GitHub/convert_MassBank_format/KI_GIAR/"
inputfile = "KI-GIAR_zic-HILIC_Pos_v0.90.msp"
outputdir ="/Users/donghanli/Documents/GitHub/convert_MassBank_format/KI_GIAR/KI_Gumma/"
with open(inputdir+inputfile, "r") as f:
    readdata = f.read()
filelist = readdata.split("\n\n")
filelist = filelist[:-2]
with open(inputdir+"classlist.json","r") as f:
    classlist =json.loads(f.read())
data = []
faillist = []
successlist=[]
finallist =[]
name, formula, smiles, mol, inchi, instrmt_type, msn="","","","","","",""

# %%
def dateformat(date):
    date = date.replace("/",".")
    date = date.replace("-",".")
    y,m,d = date.split(".")
    MBdate = y+"."+format(int(m),"02d")+"."+format(int(d),"02d")
    return(MBdate)

def calculate_weight(chem):     # <string> formula. 
	s = re.findall('([A-Z][a-z]?)([0-9]*)', chem)
	compoundweight = 0
	for element, count in s:
		count = int(count or '1')
		compoundweight += atom[element] * count
	return compoundweight      # <float> formula weight

def searchsingle(tokeyword,fromkeyword1, fromkeyword2="\n", search = "ON"):
    temp = fromkeyword1
    tempfield = ""
    if search == "ON":
        temp = data.split(fromkeyword1)[1].split(fromkeyword2)[0]
        if temp.upper() == "POSITIVE" or temp.upper() =="NEGATIVE":
            temp = temp.upper()
        elif temp == "MS1":
            temp = "MS"
        tempfield = tokeyword+temp
    elif search =="OFF":
        tempfield = tokeyword+fromkeyword1
    finallist.append(tempfield)
    return temp

def searchmulti(tokeyword, fromkeyword, ignore = ""):
    searchlen = len(fromkeyword)
    ignorelen = len(ignore)
    temp = [k for k in data.split("\n") if k[:searchlen] == fromkeyword]
    temp = list(set(temp))
    if ignore != "":
        for j in reversed(range(len(temp))):
            if temp[j][-ignorelen:]==ignore:
                del temp[j]
    tempfield = "\n".join(temp)
    tempfield = tempfield.replace(fromkeyword, tokeyword)
    finallist.append(tempfield)
    return temp

def peakprocess(beginline, endline="END", annotation=""):
    peakX=[]
    peakY=[]
    anno=[]
    if endline =="END":
        peakinfo = data.split(beginline)[1].split("\n")[1:]
    else:
        peakinfo1 = data.split(beginline)[1].split("\n")[1:]
        peakinfo2 = "\n".join(peakinfo1).split(endline)[0]
        peakinfo = peakinfo2.split("\n")[:-1]
    if annotation != "":
        tempinfo = [peakinfo[0]]
        for i in range(1,len(peakinfo)):
            if (peakinfo[i-1].split(annotation)[0] != peakinfo[i].split(annotation)[0]):
                tempinfo.append(peakinfo[i])
        peakinfo = tempinfo
        for i in range(len(peakinfo)):
            calpeakinfo = peakinfo[i].split(annotation)[0]
            calpeakinfo = calpeakinfo.strip()
            calpeakinfo = calpeakinfo.replace(" ","\t")
            peakX.append(float(calpeakinfo.split("\t")[0]))
            peakY.append(float(calpeakinfo.split("\t")[1]))
        pairpeak = list(sorted(zip(peakX, peakY)))
        spectrum = Spectrum(pairpeak, SpectrumType.MS)
        SPNO = "PK$SPLASH: "+ Splash().splash(spectrum)
        pknum= "PK$NUM_PEAK: " + str(len(pairpeak))
        maxY=max(peakY)
        pklist="PK$PEAK: m/z int. rel.int.\n"
        for i in range(len(pairpeak)):
            pklist+=("  "+str(pairpeak[i][0])+" "+str(pairpeak[i][1])+" "+str(round(pairpeak[i][1]/maxY*999))+"\n")
        pklist+="//"
        pkanno ="PK$ANNOTATION: m/z annotation\n"
        for i in range(len(peakinfo)):
            anno= peakinfo[i].split("\"")[1]
            anno = anno.replace(";", "\\")
            anno = anno.replace(" ","_")
            anno = anno.replace("\\_","\\")
            pkanno +=("  "+str(pairpeak[i][0])+" "+anno+"\n")
        pkanno = pkanno[:-2]
        finallist.extend([SPNO,pkanno,pknum,pklist])
        return None
    elif annotation == "":
        for i in range(len(peakinfo)):
            calpeakinfo = peakinfo[i].strip()
            calpeakinfo = calpeakinfo.replace(" ","\t")
            peakX.append(float(calpeakinfo.split("\t")[0]))
            peakY.append(float(calpeakinfo.split("\t")[1]))
        pairpeak = list(sorted(zip(peakX, peakY)))
        spectrum = Spectrum(pairpeak, SpectrumType.MS)
        SPNO = "PK$SPLASH: "+ Splash().splash(spectrum)
        pknum= "PK$NUM_PEAK: " + str(len(pairpeak))
        maxY=max(peakY)
        pklist="PK$PEAK: m/z int. rel.int.\n"
        for i in range(len(pairpeak)):
            pklist+=("  "+str(pairpeak[i][0])+" "+str(pairpeak[i][1])+" "+str(round(pairpeak[i][1]/maxY*999))+"\n")
        pklist+="//"
        finallist.extend([SPNO,pknum,pklist])
        return None
    
def inserttitle(n,i,m):
    title="RECORD_TITLE: "+n+"; "+i+"; "+m
    finallist.insert(1,title)
    return None

def standardASCii(finallist):
    newstring = "\n".join(finallist)
    newstring = newstring.replace("á","a")
    newstring = newstring.replace("‐","-")
    newstring = newstring.replace("™","")
    newstring = newstring.replace(" "," ")
    newstring = newstring.replace("′","'")
    newstring = newstring.replace(" 　","")
    newstring = newstring.replace("　","")
    newstring = newstring.replace("フジッコ,","")
    newstring = newstring.replace("α","alpha")
    newstring = newstring.replace("µm","um")
    return newstring

def adjustor2(base = "SMILES"):
    if base == "SMILES":
        s = smiles
        m = Chem.MolFromSmiles(s)
        i = Chem.MolToInchi(m)
        ik= Chem.inchi.MolToInchiKey(m)
        f = Chem.rdMolDescriptors.CalcMolFormula(mol)
        if f[-1]=="+" or f[-1]=="-":
            f = "["+f[:-1]+"]"+f[-1]
        w = str(round(calculate_weight(f),4))
    elif base == "INCHI":
        i = inchi
        m = Chem.MolFromInchi(i)
        s = Chem.MolToSmiles(m)
        ik= Chem.inchi.MolToInchiKey(m)
        f = Chem.rdMolDescriptors.CalcMolFormula(mol)
        if f[-1]=="+" or f[-1]=="-":
            f = "["+f[:-1]+"]"+f[-1]
        w = str(round(calculate_weight(f),4)) 
    templist =["CH$SMILES: "+s if item.find("CH$SMILES: ")==0 else item for item in finallist]
    templist =["CH$IUPAC: "+i if item.find("CH$IUPAC: ")==0 else item for item in templist]
    templist =["CH$LINK: INCHIKEY "+ik if item.find("CH$LINK: INCHIKEY ")==0 else item for item in templist]
    templist =["CH$FORMULA: "+f if item.find("CH$FORMULA:")==0 else item for item in templist]
    templist =["CH$EXACT_MASS: "+w if item.find("CH$EXACT_MASS: ")==0 else item for item in templist]
    return templist
    
def adjustor():
    tempf = formula
    mol = Chem.MolFromSmiles(smiles)
    f2 = Chem.rdMolDescriptors.CalcMolFormula(mol)
    if f2[:-1] == formula:
        tempf= "["+f2[:-1]+"]"+f2[-1]
    elif f2 != formula and formula != f2[:-1]:
        faillist.append(name + " Bad SMILES/formula: ")
        print("Fail: Bad SMILES/Formula.")
        return False
    templist =["CH$FORMULA: "+tempf if item.find("CH$FORMULA:")==0 else item for item in finallist]
    templist =["CH$EXACT_MASS: "+str(round(calculate_weight(tempf),4)) if item.find("CH$EXACT_MASS: ")==0 else item for item in templist]
    return templist

# %%
#for i in range(len(filelist)):
k1=time.time()
smilelist=[]
for i, data in enumerate(filelist):
    finallist =[]
    name, formula, smiles, mol, inchi, instrmt_type, msn="","","","","","",""
    #data = filelist[i]
    print("i=",i)
    prefix = "TMP"
    accession = searchsingle("ACCESSION: "+prefix, format(i+1, "0"+str(8-len(prefix))+"d"), search="OFF")
    searchsingle("DATE: ","2019.06.10", search = "OFF")
    searchsingle("AUTHORS: ","AUTHORS: ")
    searchsingle("LICENSE: ","LICENSE: ")
    searchsingle("COMMENT: ","COMMENT: ")
    name = searchsingle("CH$NAME: ","NAME: ",";")
    inchikey = searchsingle("inchikey:", "INCHIKEY: ")
    inchikey = "InChIKey="+inchikey
    finallist.pop()
    try:
        class1 = classlist[inchikey]
    except KeyError: 
        print("No such class")
        continue
    else:
        searchsingle("CH$COMPOUND_CLASS: ",class1, search = "OFF")
    #class1 = classlist[inchikey]
    #searchsingle("CH$COMPOUND_CLASS: ",class1, search = "OFF")
    formula = searchsingle("CH$FORMULA: ","FORMULA: ")
    searchsingle("CH$EXACT_MASS: ",str(round(calculate_weight(formula),4)),search = "OFF")
    smiles = searchsingle("CH$SMILES: ","SMILES: ")
    print(smiles)
    mol = Chem.MolFromSmiles(smiles)
    inchi = searchsingle("CH$IUPAC: ", "INCHI: ")
    searchsingle("CH$LINK: INCHIKEY ","INCHIKEY: ")
    searchsingle("AC$INSTRUMENT: ", "INSTRUMENT: ")
    instrmt_type = searchsingle("AC$INSTRUMENT_TYPE: ", "INSTRUMENTTYPE: ")
    msn = searchsingle("AC$MASS_SPECTROMETRY: MS_TYPE ", "MSLEVEL: ")
    searchsingle("AC$MASS_SPECTROMETRY: ION_MODE ","IONMODE: ")
    searchsingle("AC$MASS_SPECTROMETRY: IONIZATION ", "IONISATION: ")
    searchsingle("AC$MASS_SPECTROMETRY: COLLISION_ENERGY ", "COLLISIONENERGY: ")
    searchsingle("AC$CHROMATOGRAPHY: COLUMN_NAME ","COLUMN: ")
    searchsingle("AC$CHROMATOGRAPHY: FLOW_GRADIENT ", "FlowGradient: ")
    searchsingle("AC$CHROMATOGRAPHY: FLOW_RATE ","FlowRate: ")
    searchsingle("AC$CHROMATOGRAPHY: RETENTION_TIME ", "RETENTIONTIME: ")
    searchsingle("AC$CHROMATOGRAPHY: SOLVENT A ", "SolventA: ")
    searchsingle("AC$CHROMATOGRAPHY: SOLVENT B ", "SolventB: ")
    searchsingle("MS$FOCUSED_ION: PRECURSOR_TYPE ", "PRECURSORTYPE: ")
    searchsingle("MS$FOCUSED_ION: PRECURSOR_M/Z ", "PRECURSORMZ: ")
    peakprocess("Num Peaks", annotation="\"")
    inserttitle(name,instrmt_type,msn)
    finallist = adjustor()
    #finallist = adjustor2("INCHI")
    if finallist != False:
        finalstr = standardASCii(finallist)
        print(prefix+accession+" success.")
        smilelist.append(smiles)
        with open(outputdir+prefix+accession+".txt", "w") as f:
            f.write(finalstr)
k2=time.time()            
print(k2-k1)
with open(outputdir+"faillist.txt", "w") as f:
    f.writelines(faillist)
# Out:
# i= 0
# C1CCN(CC1)C(=O)/C=C/C=C/c1ccc2c(c1)OCO2
# TMP00001 success.
# i= 1
# C1CCN(CC1)C(=O)/C=C/C=C/c1ccc2c(c1)OCO2
# TMP00002 success.
# i= 2
# C1CCN(CC1)C(=O)/C=C/C=C/c1ccc2c(c1)OCO2
# TMP00003 success.
# i= 3
# C1CCN(CC1)C(=O)/C=C/C=C/c1ccc2c(c1)OCO2
# TMP00004 success.
# i= 4
# C1CCN(CC1)C(=O)/C=C/C=C/c1ccc2c(c1)OCO2
# TMP00005 success.
# i= 5
# C1CCN(CC1)C(=O)/C=C/C=C/c1ccc2c(c1)OCO2
# TMP00006 success.
# i= 6
# CC(=O)c1cnccn1
# TMP00007 success.
# i= 7
# CC(=O)c1cnccn1
# TMP00008 success.
# i= 8
# CC(=O)c1cnccn1
# TMP00009 success.
# i= 9
# CC(=O)c1cnccn1
# TMP00010 success.
# i= 10
# CC(=O)c1cnccn1
# TMP00011 success.
# i= 11
# CC(=O)c1cnccn1
# TMP00012 success.
# i= 12
# c1ccc2c(c1)nc(O)o2
# TMP00013 success.
# i= 13
# c1ccc2c(c1)nc(O)o2
# TMP00014 success.
# i= 14
# c1ccc2c(c1)nc(O)o2
# TMP00015 success.
# i= 15
# c1ccc2c(c1)nc(O)o2
# TMP00016 success.
# i= 16
# c1ccc2c(c1)nc(O)o2
# TMP00017 success.
# i= 17
# c1ccc2c(c1)nc(O)o2
# TMP00018 success.
# i= 18
# COC(=O)c1c(N)nccn1
# TMP00019 success.
# i= 19
# COC(=O)c1c(N)nccn1
# TMP00020 success.
# i= 20
# COC(=O)c1c(N)nccn1
# TMP00021 success.
# i= 21
# COC(=O)c1c(N)nccn1
# TMP00022 success.
# i= 22
# COC(=O)c1c(N)nccn1
# TMP00023 success.
# i= 23
# COC(=O)c1c(N)nccn1
# TMP00024 success.
# i= 24
# c1ccc(c(c1)C(=O)O)N
# TMP00025 success.
# i= 25
# c1ccc(c(c1)C(=O)O)N
# TMP00026 success.
# i= 26
# c1ccc(c(c1)C(=O)O)N
# TMP00027 success.
# i= 27
# c1ccc(c(c1)C(=O)O)N
# TMP00028 success.
# i= 28
# c1ccc(c(c1)C(=O)O)N
# TMP00029 success.
# i= 29
# c1ccc(c(c1)C(=O)O)N
# TMP00030 success.
# i= 30
# c1ccc2c(c1)ccc(C(=O)O)n2
# TMP00031 success.
# i= 31
# c1ccc2c(c1)ccc(C(=O)O)n2
# TMP00032 success.
# i= 32
# c1ccc2c(c1)ccc(C(=O)O)n2
# TMP00033 success.
# i= 33
# c1ccc2c(c1)ccc(C(=O)O)n2
# TMP00034 success.
# i= 34
# c1ccc2c(c1)ccc(C(=O)O)n2
# TMP00035 success.
# i= 35
# c1ccc2c(c1)ccc(C(=O)O)n2
# TMP00036 success.
# i= 36
# c1ccc2c(c1)c(CC(=O)O)c[nH]2
# TMP00037 success.
# i= 37
# c1ccc2c(c1)c(CC(=O)O)c[nH]2
# TMP00038 success.
# i= 38
# c1ccc2c(c1)c(CC(=O)O)c[nH]2
# TMP00039 success.
# i= 39
# c1ccc2c(c1)c(CC(=O)O)c[nH]2
# TMP00040 success.
# i= 40
# c1ccc2c(c1)c(CC(=O)O)c[nH]2
# TMP00041 success.
# i= 41
# c1ccc2c(c1)c(CC(=O)O)c[nH]2
# TMP00042 success.
# i= 42
# Cn1cnc2c1c(=O)n(C)c(=O)n2C
# TMP00043 success.
# i= 43
# Cn1cnc2c1c(=O)n(C)c(=O)n2C
# TMP00044 success.
# i= 44
# Cn1cnc2c1c(=O)n(C)c(=O)n2C
# TMP00045 success.
# i= 45
# Cn1cnc2c1c(=O)n(C)c(=O)n2C
# TMP00046 success.
# i= 46
# Cn1cnc2c1c(=O)n(C)c(=O)n2C
# TMP00047 success.
# i= 47
# Cn1cnc2c1c(=O)n(C)c(=O)n2C
# TMP00048 success.
# i= 48
# c1ccc(cc1)/C=C/C(=NCC(=O)O)O
# TMP00049 success.
# i= 49
# c1ccc(cc1)/C=C/C(=NCC(=O)O)O
# TMP00050 success.
# i= 50
# c1ccc(cc1)/C=C/C(=NCC(=O)O)O
# TMP00051 success.
# i= 51
# c1ccc(cc1)/C=C/C(=NCC(=O)O)O
# TMP00052 success.
# i= 52
# c1ccc(cc1)/C=C/C(=NCC(=O)O)O
# TMP00053 success.
# i= 53
# c1ccc(cc1)/C=C/C(=NCC(=O)O)O
# TMP00054 success.
# i= 54
# c1ccc(cc1)C(=NCC(=O)O)O
# TMP00055 success.
# i= 55
# c1ccc(cc1)C(=NCC(=O)O)O
# TMP00056 success.
# i= 56
# c1ccc(cc1)C(=NCC(=O)O)O
# TMP00057 success.
# i= 57
# c1ccc(cc1)C(=NCC(=O)O)O
# TMP00058 success.
# i= 58
# c1ccc(cc1)C(=NCC(=O)O)O
# TMP00059 success.
# i= 59
# c1ccc(cc1)C(=NCC(=O)O)O
# TMP00060 success.
# i= 60
# c1cc(c(cc1N)O)C(=O)O
# TMP00061 success.
# i= 61
# c1cc(c(cc1N)O)C(=O)O
# TMP00062 success.
# i= 62
# c1cc(c(cc1N)O)C(=O)O
# TMP00063 success.
# i= 63
# c1cc(c(cc1N)O)C(=O)O
# TMP00064 success.
# i= 64
# c1cc(c(cc1N)O)C(=O)O
# TMP00065 success.
# i= 65
# c1cc(c(cc1N)O)C(=O)O
# TMP00066 success.
# i= 66
# C[C@H](CCC(=O)O)[C@H]1CC[C@H]2[C@H]3[C@H](CC[C@]12C)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00067 success.
# i= 67
# C[C@H](CCC(=O)O)[C@H]1CC[C@H]2[C@H]3[C@H](CC[C@]12C)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00068 success.
# i= 68
# C[C@H](CCC(=O)O)[C@H]1CC[C@H]2[C@H]3[C@H](CC[C@]12C)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00069 success.
# i= 69
# C[C@H](CCC(=O)O)[C@H]1CC[C@H]2[C@H]3[C@H](CC[C@]12C)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00070 success.
# i= 70
# C[C@H](CCC(=O)O)[C@H]1CC[C@H]2[C@H]3[C@H](CC[C@]12C)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00071 success.
# i= 71
# C[C@H](CCC(=O)O)[C@H]1CC[C@H]2[C@H]3[C@H](CC[C@]12C)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00072 success.
# i= 72
# c1ccc(c(c1)C(=NCC(=O)O)O)O
# TMP00073 success.
# i= 73
# c1ccc(c(c1)C(=NCC(=O)O)O)O
# TMP00074 success.
# i= 74
# c1ccc(c(c1)C(=NCC(=O)O)O)O
# TMP00075 success.
# i= 75
# c1ccc(c(c1)C(=NCC(=O)O)O)O
# TMP00076 success.
# i= 76
# c1ccc(c(c1)C(=NCC(=O)O)O)O
# TMP00077 success.
# i= 77
# c1ccc(c(c1)C(=NCC(=O)O)O)O
# TMP00078 success.
# i= 78
# CC(=Nc1ccc(cc1)O)O
# TMP00079 success.
# i= 79
# CC(=Nc1ccc(cc1)O)O
# TMP00080 success.
# i= 80
# CC(=Nc1ccc(cc1)O)O
# TMP00081 success.
# i= 81
# CC(=Nc1ccc(cc1)O)O
# TMP00082 success.
# i= 82
# CC(=Nc1ccc(cc1)O)O
# TMP00083 success.
# i= 83
# CC(=Nc1ccc(cc1)O)O
# TMP00084 success.
# i= 84
# c1ccc2c(c1)c(c[nH]2)C(=O)O
# TMP00085 success.
# i= 85
# c1ccc2c(c1)c(c[nH]2)C(=O)O
# TMP00086 success.
# i= 86
# c1ccc2c(c1)c(c[nH]2)C(=O)O
# TMP00087 success.
# i= 87
# c1ccc2c(c1)c(c[nH]2)C(=O)O
# TMP00088 success.
# i= 88
# c1ccc2c(c1)c(c[nH]2)C(=O)O
# TMP00089 success.
# i= 89
# c1ccc2c(c1)c(c[nH]2)C(=O)O
# TMP00090 success.
# i= 90
# Cn1c2c(c(=O)n(C)c1=O)nc[nH]2
# TMP00091 success.
# i= 91
# Cn1c2c(c(=O)n(C)c1=O)nc[nH]2
# TMP00092 success.
# i= 92
# Cn1c2c(c(=O)n(C)c1=O)nc[nH]2
# TMP00093 success.
# i= 93
# Cn1c2c(c(=O)n(C)c1=O)nc[nH]2
# TMP00094 success.
# i= 94
# Cn1c2c(c(=O)n(C)c1=O)nc[nH]2
# TMP00095 success.
# i= 95
# Cn1c2c(c(=O)n(C)c1=O)nc[nH]2
# TMP00096 success.
# i= 96
# Cn1cnc2c1c(nc(=O)n2C)O
# TMP00097 success.
# i= 97
# Cn1cnc2c1c(nc(=O)n2C)O
# TMP00098 success.
# i= 98
# Cn1cnc2c1c(nc(=O)n2C)O
# TMP00099 success.
# i= 99
# Cn1cnc2c1c(nc(=O)n2C)O
# TMP00100 success.
# i= 100
# Cn1cnc2c1c(nc(=O)n2C)O
# TMP00101 success.
# i= 101
# Cn1cnc2c1c(nc(=O)n2C)O
# TMP00102 success.
# i= 102
# C(COCCOCCOCCOCCOCCO)O
# TMP00103 success.
# i= 103
# C(COCCOCCOCCOCCOCCO)O
# TMP00104 success.
# i= 104
# C(COCCOCCOCCOCCOCCO)O
# TMP00105 success.
# i= 105
# C(COCCOCCOCCOCCOCCO)O
# TMP00106 success.
# i= 106
# C(COCCOCCOCCOCCOCCO)O
# TMP00107 success.
# i= 107
# C(COCCOCCOCCOCCOCCO)O
# TMP00108 success.
# i= 108
# C1CCN=C(C1)O
# TMP00109 success.
# i= 109
# C1CCN=C(C1)O
# TMP00110 success.
# i= 110
# C1CCN=C(C1)O
# TMP00111 success.
# i= 111
# C1CCN=C(C1)O
# TMP00112 success.
# i= 112
# C1CCN=C(C1)O
# TMP00113 success.
# i= 113
# C1CCN=C(C1)O
# TMP00114 success.
# i= 114
# C[C@H](CCC(=O)O)[C@H]1CC[C@H]2[C@H]3[C@H](C[C@@H]([C@]12C)O)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00115 success.
# i= 115
# C[C@H](CCC(=O)O)[C@H]1CC[C@H]2[C@H]3[C@H](C[C@@H]([C@]12C)O)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00116 success.
# i= 116
# C[C@H](CCC(=O)O)[C@H]1CC[C@H]2[C@H]3[C@H](C[C@@H]([C@]12C)O)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00117 success.
# i= 117
# C[C@H](CCC(=O)O)[C@H]1CC[C@H]2[C@H]3[C@H](C[C@@H]([C@]12C)O)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00118 success.
# i= 118
# C[C@H](CCC(=O)O)[C@H]1CC[C@H]2[C@H]3[C@H](C[C@@H]([C@]12C)O)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00119 success.
# i= 119
# C[C@H](CCC(=O)O)[C@H]1CC[C@H]2[C@H]3[C@H](C[C@@H]([C@]12C)O)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00120 success.
# i= 120
# c1cc(cnc1)C(=O)O
# TMP00121 success.
# i= 121
# c1cc(cnc1)C(=O)O
# TMP00122 success.
# i= 122
# c1cc(cnc1)C(=O)O
# TMP00123 success.
# i= 123
# c1cc(cnc1)C(=O)O
# TMP00124 success.
# i= 124
# c1cc(cnc1)C(=O)O
# TMP00125 success.
# i= 125
# c1cc(cnc1)C(=O)O
# TMP00126 success.
# i= 126
# CN(C)C(=N)NCCC[C@@H](C(=O)O)N
# TMP00127 success.
# i= 127
# CN(C)C(=N)NCCC[C@@H](C(=O)O)N
# TMP00128 success.
# i= 128
# CN(C)C(=N)NCCC[C@@H](C(=O)O)N
# TMP00129 success.
# i= 129
# CN(C)C(=N)NCCC[C@@H](C(=O)O)N
# TMP00130 success.
# i= 130
# CN(C)C(=N)NCCC[C@@H](C(=O)O)N
# TMP00131 success.
# i= 131
# CN(C)C(=N)NCCC[C@@H](C(=O)O)N
# TMP00132 success.
# i= 132
# C(c1cnc[nH]1)[C@@H](C(=O)O)N
# TMP00133 success.
# i= 133
# C(c1cnc[nH]1)[C@@H](C(=O)O)N
# TMP00134 success.
# i= 134
# C(c1cnc[nH]1)[C@@H](C(=O)O)N
# TMP00135 success.
# i= 135
# C(c1cnc[nH]1)[C@@H](C(=O)O)N
# TMP00136 success.
# i= 136
# C(c1cnc[nH]1)[C@@H](C(=O)O)N
# TMP00137 success.
# i= 137
# C(c1cnc[nH]1)[C@@H](C(=O)O)N
# TMP00138 success.
# i= 138
# C(C[C@@H](C(=O)O)N)CNC(=N)N
# TMP00139 success.
# i= 139
# C(C[C@@H](C(=O)O)N)CNC(=N)N
# TMP00140 success.
# i= 140
# C(C[C@@H](C(=O)O)N)CNC(=N)N
# TMP00141 success.
# i= 141
# C(C[C@@H](C(=O)O)N)CNC(=N)N
# TMP00142 success.
# i= 142
# C(C[C@@H](C(=O)O)N)CNC(=N)N
# TMP00143 success.
# i= 143
# C(C[C@@H](C(=O)O)N)CNC(=N)N
# TMP00144 success.
# i= 144
# Cn1cncc1C[C@@H](C(=O)O)N=C(CCN)O
# TMP00145 success.
# i= 145
# Cn1cncc1C[C@@H](C(=O)O)N=C(CCN)O
# TMP00146 success.
# i= 146
# Cn1cncc1C[C@@H](C(=O)O)N=C(CCN)O
# TMP00147 success.
# i= 147
# Cn1cncc1C[C@@H](C(=O)O)N=C(CCN)O
# TMP00148 success.
# i= 148
# Cn1cncc1C[C@@H](C(=O)O)N=C(CCN)O
# TMP00149 success.
# i= 149
# Cn1cncc1C[C@@H](C(=O)O)N=C(CCN)O
# TMP00150 success.
# i= 150
# CCCCOP(=O)(OCCCC)OCCCC
# TMP00151 success.
# i= 151
# CCCCOP(=O)(OCCCC)OCCCC
# TMP00152 success.
# i= 152
# CCCCOP(=O)(OCCCC)OCCCC
# TMP00153 success.
# i= 153
# CCCCOP(=O)(OCCCC)OCCCC
# TMP00154 success.
# i= 154
# CCCCOP(=O)(OCCCC)OCCCC
# TMP00155 success.
# i= 155
# CCCCOP(=O)(OCCCC)OCCCC
# TMP00156 success.
# i= 156
# c1cc(c(c(c1)O)N)C(=O)O
# TMP00157 success.
# i= 157
# c1cc(c(c(c1)O)N)C(=O)O
# TMP00158 success.
# i= 158
# c1cc(c(c(c1)O)N)C(=O)O
# TMP00159 success.
# i= 159
# c1cc(c(c(c1)O)N)C(=O)O
# TMP00160 success.
# i= 160
# c1cc(c(c(c1)O)N)C(=O)O
# TMP00161 success.
# i= 161
# c1cc(c(c(c1)O)N)C(=O)O
# TMP00162 success.
# i= 162
# Cc1cnc(nc1O)O
# TMP00163 success.
# i= 163
# Cc1cnc(nc1O)O
# TMP00164 success.
# i= 164
# Cc1cnc(nc1O)O
# TMP00165 success.
# i= 165
# Cc1cnc(nc1O)O
# TMP00166 success.
# i= 166
# Cc1cnc(nc1O)O
# TMP00167 success.
# i= 167
# Cc1cnc(nc1O)O
# TMP00168 success.
# i= 168
# CN=C(c1cccnc1)O
# TMP00169 success.
# i= 169
# CN=C(c1cccnc1)O
# TMP00170 success.
# i= 170
# CN=C(c1cccnc1)O
# TMP00171 success.
# i= 171
# CN=C(c1cccnc1)O
# TMP00172 success.
# i= 172
# CN=C(c1cccnc1)O
# TMP00173 success.
# i= 173
# CN=C(c1cccnc1)O
# TMP00174 success.
# i= 174
# CC(C)(CO)C(C(=NCCC(=O)O)O)O
# TMP00175 success.
# i= 175
# CC(C)(CO)C(C(=NCCC(=O)O)O)O
# TMP00176 success.
# i= 176
# CC(C)(CO)C(C(=NCCC(=O)O)O)O
# TMP00177 success.
# i= 177
# CC(C)(CO)C(C(=NCCC(=O)O)O)O
# TMP00178 success.
# i= 178
# CC(C)(CO)C(C(=NCCC(=O)O)O)O
# TMP00179 success.
# i= 179
# CC(C)(CO)C(C(=NCCC(=O)O)O)O
# TMP00180 success.
# i= 180
# CN1CCCN=C1/C=C/c1cccs1
# TMP00181 success.
# i= 181
# CN1CCCN=C1/C=C/c1cccs1
# TMP00182 success.
# i= 182
# CN1CCCN=C1/C=C/c1cccs1
# TMP00183 success.
# i= 183
# CN1CCCN=C1/C=C/c1cccs1
# TMP00184 success.
# i= 184
# CN1CCCN=C1/C=C/c1cccs1
# TMP00185 success.
# i= 185
# CN1CCCN=C1/C=C/c1cccs1
# TMP00186 success.
# i= 186
# C1CC(=N[C@@H]1C(=O)O)O
# TMP00187 success.
# i= 187
# C1CC(=N[C@@H]1C(=O)O)O
# TMP00188 success.
# i= 188
# C1CC(=N[C@@H]1C(=O)O)O
# TMP00189 success.
# i= 189
# C1CC(=N[C@@H]1C(=O)O)O
# TMP00190 success.
# i= 190
# C1CC(=N[C@@H]1C(=O)O)O
# TMP00191 success.
# i= 191
# C1CC(=N[C@@H]1C(=O)O)O
# TMP00192 success.
# i= 192
# c1cnc(nc1O)O
# TMP00193 success.
# i= 193
# c1cnc(nc1O)O
# TMP00194 success.
# i= 194
# c1cnc(nc1O)O
# TMP00195 success.
# i= 195
# c1cnc(nc1O)O
# TMP00196 success.
# i= 196
# c1cnc(nc1O)O
# TMP00197 success.
# i= 197
# c1cnc(nc1O)O
# TMP00198 success.
# i= 198
# Cn1c2c(c(nc1=O)O)nc[nH]2
# TMP00199 success.
# i= 199
# Cn1c2c(c(nc1=O)O)nc[nH]2
# TMP00200 success.
# i= 200
# Cn1c2c(c(nc1=O)O)nc[nH]2
# TMP00201 success.
# i= 201
# Cn1c2c(c(nc1=O)O)nc[nH]2
# TMP00202 success.
# i= 202
# Cn1c2c(c(nc1=O)O)nc[nH]2
# TMP00203 success.
# i= 203
# Cn1c2c(c(nc1=O)O)nc[nH]2
# TMP00204 success.
# i= 204
# Cn1c(=O)c2c([nH]cn2)nc1O
# TMP00205 success.
# i= 205
# Cn1c(=O)c2c([nH]cn2)nc1O
# TMP00206 success.
# i= 206
# Cn1c(=O)c2c([nH]cn2)nc1O
# TMP00207 success.
# i= 207
# Cn1c(=O)c2c([nH]cn2)nc1O
# TMP00208 success.
# i= 208
# Cn1c(=O)c2c([nH]cn2)nc1O
# TMP00209 success.
# i= 209
# Cn1c(=O)c2c([nH]cn2)nc1O
# TMP00210 success.
# i= 210
# c1cc(cnc1)C(=N)O
# TMP00211 success.
# i= 211
# c1cc(cnc1)C(=N)O
# TMP00212 success.
# i= 212
# c1cc(cnc1)C(=N)O
# TMP00213 success.
# i= 213
# c1cc(cnc1)C(=N)O
# TMP00214 success.
# i= 214
# c1cc(cnc1)C(=N)O
# TMP00215 success.
# i= 215
# c1ccc2c(c1)c(=O)cc(C(=O)O)[nH]2
# TMP00216 success.
# i= 216
# c1ccc2c(c1)c(=O)cc(C(=O)O)[nH]2
# TMP00217 success.
# i= 217
# c1ccc2c(c1)c(=O)cc(C(=O)O)[nH]2
# TMP00218 success.
# i= 218
# c1ccc2c(c1)c(=O)cc(C(=O)O)[nH]2
# TMP00219 success.
# i= 219
# c1ccc2c(c1)c(=O)cc(C(=O)O)[nH]2
# TMP00220 success.
# i= 220
# c1ccc2c(c1)c(=O)cc(C(=O)O)[nH]2
# TMP00221 success.
# i= 221
# CC(=O)OCC[N+](C)(C)C
# TMP00222 success.
# i= 222
# CC(=O)OCC[N+](C)(C)C
# TMP00223 success.
# i= 223
# CC(=O)OCC[N+](C)(C)C
# TMP00224 success.
# i= 224
# CC(=O)OCC[N+](C)(C)C
# TMP00225 success.
# i= 225
# CC(=O)OCC[N+](C)(C)C
# TMP00226 success.
# i= 226
# CC(=O)OCC[N+](C)(C)C
# TMP00227 success.
# i= 227
# C[C@H](CCC(=NCC(=O)O)O)[C@H]1CC[C@H]2[C@H]3[C@H](C[C@@H]([C@]12C)O)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00228 success.
# i= 228
# C[C@H](CCC(=NCC(=O)O)O)[C@H]1CC[C@H]2[C@H]3[C@H](C[C@@H]([C@]12C)O)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00229 success.
# i= 229
# C[C@H](CCC(=NCC(=O)O)O)[C@H]1CC[C@H]2[C@H]3[C@H](C[C@@H]([C@]12C)O)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00230 success.
# i= 230
# C[C@H](CCC(=NCC(=O)O)O)[C@H]1CC[C@H]2[C@H]3[C@H](C[C@@H]([C@]12C)O)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00231 success.
# i= 231
# C[C@H](CCC(=NCC(=O)O)O)[C@H]1CC[C@H]2[C@H]3[C@H](C[C@@H]([C@]12C)O)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00232 success.
# i= 232
# C[C@H](CCC(=NCC(=O)O)O)[C@H]1CC[C@H]2[C@H]3[C@H](C[C@@H]([C@]12C)O)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00233 success.
# i= 233
# CC(=N[C@@H](CC(=O)O)C(=O)O)O
# TMP00234 success.
# i= 234
# CC(=N[C@@H](CC(=O)O)C(=O)O)O
# TMP00235 success.
# i= 235
# CC(=N[C@@H](CC(=O)O)C(=O)O)O
# TMP00236 success.
# i= 236
# CC(=N[C@@H](CC(=O)O)C(=O)O)O
# TMP00237 success.
# i= 237
# CC(=N[C@@H](CC(=O)O)C(=O)O)O
# TMP00238 success.
# i= 238
# CC(=N[C@@H](CC(=O)O)C(=O)O)O
# TMP00239 success.
# i= 239
# c1cc(c(nc1)O)O
# TMP00240 success.
# i= 240
# c1cc(c(nc1)O)O
# TMP00241 success.
# i= 241
# c1cc(c(nc1)O)O
# TMP00242 success.
# i= 242
# c1cc(c(nc1)O)O
# TMP00243 success.
# i= 243
# c1cc(c(nc1)O)O
# TMP00244 success.
# i= 244
# c1cc(c(nc1)O)O
# TMP00245 success.
# i= 245
# c1ccnc(c1)CC(=O)O
# TMP00246 success.
# i= 246
# c1ccnc(c1)CC(=O)O
# TMP00247 success.
# i= 247
# c1ccnc(c1)CC(=O)O
# TMP00248 success.
# i= 248
# c1ccnc(c1)CC(=O)O
# TMP00249 success.
# i= 249
# c1ccnc(c1)CC(=O)O
# TMP00250 success.
# i= 250
# c1ccnc(c1)CC(=O)O
# TMP00251 success.
# i= 251
# No such class
# i= 252
# No such class
# i= 253
# No such class
# i= 254
# No such class
# i= 255
# No such class
# i= 256
# No such class
# i= 257
# C[C@H](CCC(=NCCS(=O)(=O)O)O)[C@H]1CC[C@H]2[C@H]3[C@H](C[C@@H]([C@]12C)O)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00258 success.
# i= 258
# C[C@H](CCC(=NCCS(=O)(=O)O)O)[C@H]1CC[C@H]2[C@H]3[C@H](C[C@@H]([C@]12C)O)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00259 success.
# i= 259
# C[C@H](CCC(=NCCS(=O)(=O)O)O)[C@H]1CC[C@H]2[C@H]3[C@H](C[C@@H]([C@]12C)O)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00260 success.
# i= 260
# C[C@H](CCC(=NCCS(=O)(=O)O)O)[C@H]1CC[C@H]2[C@H]3[C@H](C[C@@H]([C@]12C)O)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00261 success.
# i= 261
# C[C@H](CCC(=NCCS(=O)(=O)O)O)[C@H]1CC[C@H]2[C@H]3[C@H](C[C@@H]([C@]12C)O)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00262 success.
# i= 262
# C[C@H](CCC(=NCCS(=O)(=O)O)O)[C@H]1CC[C@H]2[C@H]3[C@H](C[C@@H]([C@]12C)O)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O
# TMP00263 success.
# i= 263
# c1nc2c([nH]1)nc(nc2O)O
# TMP00264 success.
# i= 264
# c1nc2c([nH]1)nc(nc2O)O
# TMP00265 success.
# i= 265
# c1nc2c([nH]1)nc(nc2O)O
# TMP00266 success.
# i= 266
# c1nc2c([nH]1)nc(nc2O)O
# TMP00267 success.
# i= 267
# c1nc2c([nH]1)nc(nc2O)O
# TMP00268 success.
# i= 268
# c1nc2c([nH]1)nc(nc2O)O
# TMP00269 success.
# i= 269
# c1cn([C@H]2[C@@H]([C@@H]([C@@H](CO)O2)O)O)c(=O)nc1O
# TMP00270 success.
# i= 270
# c1cn([C@H]2[C@@H]([C@@H]([C@@H](CO)O2)O)O)c(=O)nc1O
# TMP00271 success.
# i= 271
# c1cn([C@H]2[C@@H]([C@@H]([C@@H](CO)O2)O)O)c(=O)nc1O
# TMP00272 success.
# i= 272
# c1cn([C@H]2[C@@H]([C@@H]([C@@H](CO)O2)O)O)c(=O)nc1O
# TMP00273 success.
# i= 273
# c1cn([C@H]2[C@@H]([C@@H]([C@@H](CO)O2)O)O)c(=O)nc1O
# TMP00274 success.
# i= 274
# c1cn([C@H]2[C@@H]([C@@H]([C@@H](CO)O2)O)O)c(=O)nc1O
# TMP00275 success.
# i= 275
# c1nc2c([nH]1)ncnc2O
# TMP00276 success.
# i= 276
# c1nc2c([nH]1)ncnc2O
# TMP00277 success.
# i= 277
# c1nc2c([nH]1)ncnc2O
# TMP00278 success.
# i= 278
# c1nc2c([nH]1)ncnc2O
# TMP00279 success.
# i= 279
# c1nc2c([nH]1)ncnc2O
# TMP00280 success.
# i= 280
# c1nc2c([nH]1)ncnc2O
# TMP00281 success.
# i= 281
# C[N+](C)(C)[C@@H](Cc1ccccc1)C(=O)[O-]
# TMP00282 success.
# i= 282
# C[N+](C)(C)[C@@H](Cc1ccccc1)C(=O)[O-]
# TMP00283 success.
# i= 283
# C[N+](C)(C)[C@@H](Cc1ccccc1)C(=O)[O-]
# TMP00284 success.
# i= 284
# C[N+](C)(C)[C@@H](Cc1ccccc1)C(=O)[O-]
# TMP00285 success.
# i= 285
# C[N+](C)(C)[C@@H](Cc1ccccc1)C(=O)[O-]
# TMP00286 success.
# i= 286
# C[N+](C)(C)[C@@H](Cc1ccccc1)C(=O)[O-]
# TMP00287 success.
# i= 287
# C[N+](C)(C)[C@@H](Cc1c[nH]c2ccccc12)C(=O)[O-]
# TMP00288 success.
# i= 288
# C[N+](C)(C)[C@@H](Cc1c[nH]c2ccccc12)C(=O)[O-]
# TMP00289 success.
# i= 289
# C[N+](C)(C)[C@@H](Cc1c[nH]c2ccccc12)C(=O)[O-]
# TMP00290 success.
# i= 290
# C[N+](C)(C)[C@@H](Cc1c[nH]c2ccccc12)C(=O)[O-]
# TMP00291 success.
# i= 291
# C[N+](C)(C)[C@@H](Cc1c[nH]c2ccccc12)C(=O)[O-]
# TMP00292 success.
# i= 292
# C[N+](C)(C)[C@@H](Cc1c[nH]c2ccccc12)C(=O)[O-]
# TMP00293 success.
# i= 293
# C([C@@H]1[C@H]([C@H]([C@H](n2cnc3c2ncnc3O)O1)O)O)O
# TMP00294 success.
# i= 294
# C([C@@H]1[C@H]([C@H]([C@H](n2cnc3c2ncnc3O)O1)O)O)O
# TMP00295 success.
# i= 295
# C([C@@H]1[C@H]([C@H]([C@H](n2cnc3c2ncnc3O)O1)O)O)O
# TMP00296 success.
# i= 296
# C([C@@H]1[C@H]([C@H]([C@H](n2cnc3c2ncnc3O)O1)O)O)O
# TMP00297 success.
# i= 297
# C([C@@H]1[C@H]([C@H]([C@H](n2cnc3c2ncnc3O)O1)O)O)O
# TMP00298 success.
# i= 298
# C([C@@H]1[C@H]([C@H]([C@H](n2cnc3c2ncnc3O)O1)O)O)O
# TMP00299 success.
# i= 299
# CC(CCC(=O)[O-])[N+](C)(C)C
# TMP00300 success.
# i= 300
# CC(CCC(=O)[O-])[N+](C)(C)C
# TMP00301 success.
# i= 301
# CC(CCC(=O)[O-])[N+](C)(C)C
# TMP00302 success.
# i= 302
# CC(CCC(=O)[O-])[N+](C)(C)C
# TMP00303 success.
# i= 303
# CC(CCC(=O)[O-])[N+](C)(C)C
# TMP00304 success.
# i= 304
# CC(CCC(=O)[O-])[N+](C)(C)C
# TMP00305 success.
# i= 305
# CC(C)C(C(=O)[O-])[N+](C)(C)C
# TMP00306 success.
# i= 306
# CC(C)C(C(=O)[O-])[N+](C)(C)C
# TMP00307 success.
# i= 307
# CC(C)C(C(=O)[O-])[N+](C)(C)C
# TMP00308 success.
# i= 308
# CC(C)C(C(=O)[O-])[N+](C)(C)C
# TMP00309 success.
# i= 309
# CC(C)C(C(=O)[O-])[N+](C)(C)C
# TMP00310 success.
# i= 310
# CC(C)C(C(=O)[O-])[N+](C)(C)C
# TMP00311 success.
# i= 311
# C1CCC(CC1)NCCS(=O)(=O)O
# TMP00312 success.
# i= 312
# C1CCC(CC1)NCCS(=O)(=O)O
# TMP00313 success.
# i= 313
# C1CCC(CC1)NCCS(=O)(=O)O
# TMP00314 success.
# i= 314
# C1CCC(CC1)NCCS(=O)(=O)O
# TMP00315 success.
# i= 315
# C1CCC(CC1)NCCS(=O)(=O)O
# TMP00316 success.
# i= 316
# C1CCC(CC1)NCCS(=O)(=O)O
# TMP00317 success.
# i= 317
# C[N+](C)(C)CCCCC(=O)[O-]
# TMP00318 success.
# i= 318
# C[N+](C)(C)CCCCC(=O)[O-]
# TMP00319 success.
# i= 319
# C[N+](C)(C)CCCCC(=O)[O-]
# TMP00320 success.
# i= 320
# C[N+](C)(C)CCCCC(=O)[O-]
# TMP00321 success.
# i= 321
# C[N+](C)(C)CCCCC(=O)[O-]
# TMP00322 success.
# i= 322
# C[N+](C)(C)CCCCC(=O)[O-]
# TMP00323 success.
# i= 323
# CCCC(C(=O)[O-])[N+](C)(C)C
# TMP00324 success.
# i= 324
# CCCC(C(=O)[O-])[N+](C)(C)C
# TMP00325 success.
# i= 325
# CCCC(C(=O)[O-])[N+](C)(C)C
# TMP00326 success.
# i= 326
# CCCC(C(=O)[O-])[N+](C)(C)C
# TMP00327 success.
# i= 327
# CCCC(C(=O)[O-])[N+](C)(C)C
# TMP00328 success.
# i= 328
# CCCC(C(=O)[O-])[N+](C)(C)C
# TMP00329 success.
# i= 329
# CC(=N[C@@H]1[C@H]([C@@H]([C@@H](CO)OC1O)O)O)O
# TMP00330 success.
# i= 330
# CC(=N[C@@H]1[C@H]([C@@H]([C@@H](CO)OC1O)O)O)O
# TMP00331 success.
# i= 331
# CC(=N[C@@H]1[C@H]([C@@H]([C@@H](CO)OC1O)O)O)O
# TMP00332 success.
# i= 332
# CC(=N[C@@H]1[C@H]([C@@H]([C@@H](CO)OC1O)O)O)O
# TMP00333 success.
# i= 333
# CC(=N[C@@H]1[C@H]([C@@H]([C@@H](CO)OC1O)O)O)O
# TMP00334 success.
# i= 334
# CC(=N[C@@H]1[C@H]([C@@H]([C@@H](CO)OC1O)O)O)O
# TMP00335 success.
# i= 335
# c12c([nH]c(n2)O)nc(nc1O)O
# TMP00336 success.
# i= 336
# c12c([nH]c(n2)O)nc(nc1O)O
# TMP00337 success.
# i= 337
# c12c([nH]c(n2)O)nc(nc1O)O
# TMP00338 success.
# i= 338
# c12c([nH]c(n2)O)nc(nc1O)O
# TMP00339 success.
# i= 339
# c12c([nH]c(n2)O)nc(nc1O)O
# TMP00340 success.
# i= 340
# c12c([nH]c(n2)O)nc(nc1O)O
# TMP00341 success.
# i= 341
# c1cc(cnc1)O
# TMP00342 success.
# i= 342
# c1cc(cnc1)O
# TMP00343 success.
# i= 343
# c1cc(cnc1)O
# TMP00344 success.
# i= 344
# c1cc(cnc1)O
# TMP00345 success.
# i= 345
# c1cc(cnc1)O
# TMP00346 success.
# i= 346
# c1ccc(cc1)C[C@@H](C(=O)O)N
# TMP00347 success.
# i= 347
# c1ccc(cc1)C[C@@H](C(=O)O)N
# TMP00348 success.
# i= 348
# c1ccc(cc1)C[C@@H](C(=O)O)N
# TMP00349 success.
# i= 349
# c1ccc(cc1)C[C@@H](C(=O)O)N
# TMP00350 success.
# i= 350
# c1ccc(cc1)C[C@@H](C(=O)O)N
# TMP00351 success.
# i= 351
# c1ccc(cc1)C[C@@H](C(=O)O)N
# TMP00352 success.
# i= 352
# CCCCC(C(=O)O)N
# TMP00353 success.
# i= 353
# CCCCC(C(=O)O)N
# TMP00354 success.
# i= 354
# CCCCC(C(=O)O)N
# TMP00355 success.
# i= 355
# CCCCC(C(=O)O)N
# TMP00356 success.
# i= 356
# CCCCC(C(=O)O)N
# TMP00357 success.
# i= 357
# CCCCC(C(=O)O)N
# TMP00358 success.
# i= 358
# C1COCCN1CCS(=O)(=O)O
# TMP00359 success.
# i= 359
# C1COCCN1CCS(=O)(=O)O
# TMP00360 success.
# i= 360
# C1COCCN1CCS(=O)(=O)O
# TMP00361 success.
# i= 361
# C1COCCN1CCS(=O)(=O)O
# TMP00362 success.
# i= 362
# C1COCCN1CCS(=O)(=O)O
# TMP00363 success.
# i= 363
# C1COCCN1CCS(=O)(=O)O
# TMP00364 success.
# i= 364
# C1(C(=NC(=N1)O)O)NC(=N)O
# TMP00365 success.
# i= 365
# C1(C(=NC(=N1)O)O)NC(=N)O
# TMP00366 success.
# i= 366
# C1(C(=NC(=N1)O)O)NC(=N)O
# TMP00367 success.
# i= 367
# C1(C(=NC(=N1)O)O)NC(=N)O
# TMP00368 success.
# i= 368
# C1(C(=NC(=N1)O)O)NC(=N)O
# TMP00369 success.
# i= 369
# C1(C(=NC(=N1)O)O)NC(=N)O
# TMP00370 success.
# i= 370
# C[N+](C)(C)CCCC(=O)[O-]
# TMP00371 success.
# i= 371
# C[N+](C)(C)CCCC(=O)[O-]
# TMP00372 success.
# i= 372
# C[N+](C)(C)CCCC(=O)[O-]
# TMP00373 success.
# i= 373
# C[N+](C)(C)CCCC(=O)[O-]
# TMP00374 success.
# i= 374
# C[N+](C)(C)CCCC(=O)[O-]
# TMP00375 success.
# i= 375
# C[N+](C)(C)CCCC(=O)[O-]
# TMP00376 success.
# i= 376
# C([C@@H]1[C@H]([C@H]([C@H](n2cnc3c(N)ncnc23)O1)O)O)O
# TMP00377 success.
# i= 377
# C([C@@H]1[C@H]([C@H]([C@H](n2cnc3c(N)ncnc23)O1)O)O)O
# TMP00378 success.
# i= 378
# C([C@@H]1[C@H]([C@H]([C@H](n2cnc3c(N)ncnc23)O1)O)O)O
# TMP00379 success.
# i= 379
# C([C@@H]1[C@H]([C@H]([C@H](n2cnc3c(N)ncnc23)O1)O)O)O
# TMP00380 success.
# i= 380
# C([C@@H]1[C@H]([C@H]([C@H](n2cnc3c(N)ncnc23)O1)O)O)O
# TMP00381 success.
# i= 381
# C([C@@H]1[C@H]([C@H]([C@H](n2cnc3c(N)ncnc23)O1)O)O)O
# TMP00382 success.
# i= 382
# c1ccc(c(c1)C(=O)C[C@@H](C(=O)O)N)N
# TMP00383 success.
# i= 383
# c1ccc(c(c1)C(=O)C[C@@H](C(=O)O)N)N
# TMP00384 success.
# i= 384
# c1ccc(c(c1)C(=O)C[C@@H](C(=O)O)N)N
# TMP00385 success.
# i= 385
# c1ccc(c(c1)C(=O)C[C@@H](C(=O)O)N)N
# TMP00386 success.
# i= 386
# c1ccc(c(c1)C(=O)C[C@@H](C(=O)O)N)N
# TMP00387 success.
# i= 387
# c1ccc(c(c1)C(=O)C[C@@H](C(=O)O)N)N
# TMP00388 success.
# i= 388
# CC(C)C[C@@H](C(=O)O)N
# TMP00389 success.
# i= 389
# CC(C)C[C@@H](C(=O)O)N
# TMP00390 success.
# i= 390
# CC(C)C[C@@H](C(=O)O)N
# TMP00391 success.
# i= 391
# CC(C)C[C@@H](C(=O)O)N
# TMP00392 success.
# i= 392
# CC(C)C[C@@H](C(=O)O)N
# TMP00393 success.
# i= 393
# CC(C)C[C@@H](C(=O)O)N
# TMP00394 success.
# i= 394
# C([C@@H]1[C@H]([C@H]([C@H](n2cnc3c2[nH]c(=N)nc3O)O1)O)O)O
# TMP00395 success.
# i= 395
# C([C@@H]1[C@H]([C@H]([C@H](n2cnc3c2[nH]c(=N)nc3O)O1)O)O)O
# TMP00396 success.
# i= 396
# C([C@@H]1[C@H]([C@H]([C@H](n2cnc3c2[nH]c(=N)nc3O)O1)O)O)O
# TMP00397 success.
# i= 397
# C([C@@H]1[C@H]([C@H]([C@H](n2cnc3c2[nH]c(=N)nc3O)O1)O)O)O
# TMP00398 success.
# i= 398
# C([C@@H]1[C@H]([C@H]([C@H](n2cnc3c2[nH]c(=N)nc3O)O1)O)O)O
# TMP00399 success.
# i= 399
# C([C@@H]1[C@H]([C@H]([C@H](n2cnc3c2[nH]c(=N)nc3O)O1)O)O)O
# TMP00400 success.
# i= 400
# CN(=O)(C)C
# TMP00401 success.
# i= 401
# CN(=O)(C)C
# TMP00402 success.
# i= 402
# CN(=O)(C)C
# TMP00403 success.
# i= 403
# CN(=O)(C)C
# TMP00404 success.
# i= 404
# CN(=O)(C)C
# TMP00405 success.
# i= 405
# CN(=O)(C)C
# TMP00406 success.
# i= 406
# CC1CCCN1
# TMP00407 success.
# i= 407
# CC1CCCN1
# TMP00408 success.
# i= 408
# CC1CCCN1
# TMP00409 success.
# i= 409
# CC1CCCN1
# TMP00410 success.
# i= 410
# CC1CCCN1
# TMP00411 success.
# i= 411
# CC1CCCN1
# TMP00412 success.
# i= 412
# CC[C@H](C)[C@@H](C(=O)O)N
# TMP00413 success.
# i= 413
# CC[C@H](C)[C@@H](C(=O)O)N
# TMP00414 success.
# i= 414
# CC[C@H](C)[C@@H](C(=O)O)N
# TMP00415 success.
# i= 415
# CC[C@H](C)[C@@H](C(=O)O)N
# TMP00416 success.
# i= 416
# CC[C@H](C)[C@@H](C(=O)O)N
# TMP00417 success.
# i= 417
# CC[C@H](C)[C@@H](C(=O)O)N
# TMP00418 success.
# i= 418
# c1ccc2c(c1)c(C[C@@H](C(=O)O)N)c[nH]2
# TMP00419 success.
# i= 419
# c1ccc2c(c1)c(C[C@@H](C(=O)O)N)c[nH]2
# TMP00420 success.
# i= 420
# c1ccc2c(c1)c(C[C@@H](C(=O)O)N)c[nH]2
# TMP00421 success.
# i= 421
# c1ccc2c(c1)c(C[C@@H](C(=O)O)N)c[nH]2
# TMP00422 success.
# i= 422
# c1ccc2c(c1)c(C[C@@H](C(=O)O)N)c[nH]2
# TMP00423 success.
# i= 423
# c1ccc2c(c1)c(C[C@@H](C(=O)O)N)c[nH]2
# TMP00424 success.
# i= 424
# CC1(C)[C@H](C(=O)O)N2C(=O)[C@H]([C@H]2S1)N=C([C@@H](c1ccc(cc1)O)N)O
# TMP00425 success.
# i= 425
# CC1(C)[C@H](C(=O)O)N2C(=O)[C@H]([C@H]2S1)N=C([C@@H](c1ccc(cc1)O)N)O
# TMP00426 success.
# i= 426
# CC1(C)[C@H](C(=O)O)N2C(=O)[C@H]([C@H]2S1)N=C([C@@H](c1ccc(cc1)O)N)O
# TMP00427 success.
# i= 427
# CC1(C)[C@H](C(=O)O)N2C(=O)[C@H]([C@H]2S1)N=C([C@@H](c1ccc(cc1)O)N)O
# TMP00428 success.
# i= 428
# CC1(C)[C@H](C(=O)O)N2C(=O)[C@H]([C@H]2S1)N=C([C@@H](c1ccc(cc1)O)N)O
# TMP00429 success.
# i= 429
# CC1(C)[C@H](C(=O)O)N2C(=O)[C@H]([C@H]2S1)N=C([C@@H](c1ccc(cc1)O)N)O
# TMP00430 success.
# i= 430
# C[N+]1(C)CCCC[C@H]1C(=O)[O-]
# TMP00431 success.
# i= 431
# C[N+]1(C)CCCC[C@H]1C(=O)[O-]
# TMP00432 success.
# i= 432
# C[N+]1(C)CCCC[C@H]1C(=O)[O-]
# TMP00433 success.
# i= 433
# C[N+]1(C)CCCC[C@H]1C(=O)[O-]
# TMP00434 success.
# i= 434
# C[N+]1(C)CCCC[C@H]1C(=O)[O-]
# TMP00435 success.
# i= 435
# C[N+]1(C)CCCC[C@H]1C(=O)[O-]
# TMP00436 success.
# i= 436
# CSCC[C@@H](C(=O)O)N
# TMP00437 success.
# i= 437
# CSCC[C@@H](C(=O)O)N
# TMP00438 success.
# i= 438
# CSCC[C@@H](C(=O)O)N
# TMP00439 success.
# i= 439
# CSCC[C@@H](C(=O)O)N
# TMP00440 success.
# i= 440
# CSCC[C@@H](C(=O)O)N
# TMP00441 success.
# i= 441
# CSCC[C@@H](C(=O)O)N
# TMP00442 success.
# i= 442
# c1ccc(c(c1)N)O
# TMP00443 success.
# i= 443
# c1ccc(c(c1)N)O
# TMP00444 success.
# i= 444
# c1ccc(c(c1)N)O
# TMP00445 success.
# i= 445
# c1ccc(c(c1)N)O
# TMP00446 success.
# i= 446
# c1ccc(c(c1)N)O
# TMP00447 success.
# i= 447
# c1ccc(c(c1)N)O
# TMP00448 success.
# i= 448
# CC(=N[C@@H]1[C@H](C[C@](C(=O)O)(O)O[C@H]1[C@@H]([C@@H](CO)O)O)O)O
# TMP00449 success.
# i= 449
# CC(=N[C@@H]1[C@H](C[C@](C(=O)O)(O)O[C@H]1[C@@H]([C@@H](CO)O)O)O)O
# TMP00450 success.
# i= 450
# CC(=N[C@@H]1[C@H](C[C@](C(=O)O)(O)O[C@H]1[C@@H]([C@@H](CO)O)O)O)O
# TMP00451 success.
# i= 451
# CC(=N[C@@H]1[C@H](C[C@](C(=O)O)(O)O[C@H]1[C@@H]([C@@H](CO)O)O)O)O
# TMP00452 success.
# i= 452
# CC(=N[C@@H]1[C@H](C[C@](C(=O)O)(O)O[C@H]1[C@@H]([C@@H](CO)O)O)O)O
# TMP00453 success.
# i= 453
# CC(=N[C@@H]1[C@H](C[C@](C(=O)O)(O)O[C@H]1[C@@H]([C@@H](CO)O)O)O)O
# TMP00454 success.
# i= 454
# C[N+]1(C)CCC[C@H]1C(=O)[O-]
# TMP00455 success.
# i= 455
# C[N+]1(C)CCC[C@H]1C(=O)[O-]
# TMP00456 success.
# i= 456
# C[N+]1(C)CCC[C@H]1C(=O)[O-]
# TMP00457 success.
# i= 457
# C[N+]1(C)CCC[C@H]1C(=O)[O-]
# TMP00458 success.
# i= 458
# C[N+]1(C)CCC[C@H]1C(=O)[O-]
# TMP00459 success.
# i= 459
# C[N+]1(C)CCC[C@H]1C(=O)[O-]
# TMP00460 success.
# i= 460
# CN1CCC[C@H]1C(=O)O
# TMP00461 success.
# i= 461
# CN1CCC[C@H]1C(=O)O
# TMP00462 success.
# i= 462
# CN1CCC[C@H]1C(=O)O
# TMP00463 success.
# i= 463
# CN1CCC[C@H]1C(=O)O
# TMP00464 success.
# i= 464
# CN1CCC[C@H]1C(=O)O
# TMP00465 success.
# i= 465
# CN1CCC[C@H]1C(=O)O
# TMP00466 success.
# i= 466
# C[n+]1cccc(c1)C(=O)[O-]
# TMP00467 success.
# i= 467
# C[n+]1cccc(c1)C(=O)[O-]
# TMP00468 success.
# i= 468
# C[n+]1cccc(c1)C(=O)[O-]
# TMP00469 success.
# i= 469
# C[n+]1cccc(c1)C(=O)[O-]
# TMP00470 success.
# i= 470
# C[n+]1cccc(c1)C(=O)[O-]
# TMP00471 success.
# i= 471
# C[n+]1cccc(c1)C(=O)[O-]
# TMP00472 success.
# i= 472
# c1nc2c(N)nc[nH]c2n1
# TMP00473 success.
# i= 473
# c1nc2c(N)nc[nH]c2n1
# TMP00474 success.
# i= 474
# c1nc2c(N)nc[nH]c2n1
# TMP00475 success.
# i= 475
# c1nc2c(N)nc[nH]c2n1
# TMP00476 success.
# i= 476
# c1nc2c(N)nc[nH]c2n1
# TMP00477 success.
# i= 477
# c1nc2c(N)nc[nH]c2n1
# TMP00478 success.
# i= 478
# c1cc(C(=O)CC(C(=O)O)N)c(c(c1)O)N
# TMP00479 success.
# i= 479
# c1cc(C(=O)CC(C(=O)O)N)c(c(c1)O)N
# TMP00480 success.
# i= 480
# c1cc(C(=O)CC(C(=O)O)N)c(c(c1)O)N
# TMP00481 success.
# i= 481
# c1cc(C(=O)CC(C(=O)O)N)c(c(c1)O)N
# TMP00482 success.
# i= 482
# c1cc(C(=O)CC(C(=O)O)N)c(c(c1)O)N
# TMP00483 success.
# i= 483
# c1cc(C(=O)CC(C(=O)O)N)c(c(c1)O)N
# TMP00484 success.
# i= 484
# c1nc2c([nH]1)[nH]c(=N)nc2O
# TMP00485 success.
# i= 485
# c1nc2c([nH]1)[nH]c(=N)nc2O
# TMP00486 success.
# i= 486
# c1nc2c([nH]1)[nH]c(=N)nc2O
# TMP00487 success.
# i= 487
# c1nc2c([nH]1)[nH]c(=N)nc2O
# TMP00488 success.
# i= 488
# c1nc2c([nH]1)[nH]c(=N)nc2O
# TMP00489 success.
# i= 489
# c1nc2c([nH]1)[nH]c(=N)nc2O
# TMP00490 success.
# i= 490
# CC(C(=O)[O-])[N+](C)(C)C
# TMP00491 success.
# i= 491
# CC(C(=O)[O-])[N+](C)(C)C
# TMP00492 success.
# i= 492
# CC(C(=O)[O-])[N+](C)(C)C
# TMP00493 success.
# i= 493
# CC(C(=O)[O-])[N+](C)(C)C
# TMP00494 success.
# i= 494
# CC(C(=O)[O-])[N+](C)(C)C
# TMP00495 success.
# i= 495
# CC(C(=O)[O-])[N+](C)(C)C
# TMP00496 success.
# i= 496
# C[N+](C)(C)CC(=O)[O-]
# TMP00497 success.
# i= 497
# C[N+](C)(C)CC(=O)[O-]
# TMP00498 success.
# i= 498
# C[N+](C)(C)CC(=O)[O-]
# TMP00499 success.
# i= 499
# C[N+](C)(C)CC(=O)[O-]
# TMP00500 success.
# i= 500
# C[N+](C)(C)CC(=O)[O-]
# TMP00501 success.
# i= 501
# C[N+](C)(C)CC(=O)[O-]
# TMP00502 success.
# i= 502
# c1cc(ccc1C[C@@H](C(=O)O)N)O
# TMP00503 success.
# i= 503
# c1cc(ccc1C[C@@H](C(=O)O)N)O
# TMP00504 success.
# i= 504
# c1cc(ccc1C[C@@H](C(=O)O)N)O
# TMP00505 success.
# i= 505
# c1cc(ccc1C[C@@H](C(=O)O)N)O
# TMP00506 success.
# i= 506
# c1cc(ccc1C[C@@H](C(=O)O)N)O
# TMP00507 success.
# i= 507
# c1cc(ccc1C[C@@H](C(=O)O)N)O
# TMP00508 success.
# i= 508
# C(CC(=O)O)CNC(=N)N
# TMP00509 success.
# i= 509
# C(CC(=O)O)CNC(=N)N
# TMP00510 success.
# i= 510
# C(CC(=O)O)CNC(=N)N
# TMP00511 success.
# i= 511
# C(CC(=O)O)CNC(=N)N
# TMP00512 success.
# i= 512
# C(CC(=O)O)CNC(=N)N
# TMP00513 success.
# i= 513
# C(CC(=O)O)CNC(=N)N
# TMP00514 success.
# i= 514
# C1C[C@@H](C(=O)O)NC1
# TMP00515 success.
# i= 515
# C1C[C@@H](C(=O)O)NC1
# TMP00516 success.
# i= 516
# C1C[C@@H](C(=O)O)NC1
# TMP00517 success.
# i= 517
# C1C[C@@H](C(=O)O)NC1
# TMP00518 success.
# i= 518
# C1C[C@@H](C(=O)O)NC1
# TMP00519 success.
# i= 519
# C1C[C@@H](C(=O)O)NC1
# TMP00520 success.
# i= 520
# C1CCN[C@@H](C1)C(=O)O
# TMP00521 success.
# i= 521
# C1CCN[C@@H](C1)C(=O)O
# TMP00522 success.
# i= 522
# C1CCN[C@@H](C1)C(=O)O
# TMP00523 success.
# i= 523
# C1CCN[C@@H](C1)C(=O)O
# TMP00524 success.
# i= 524
# C1CCN[C@@H](C1)C(=O)O
# TMP00525 success.
# i= 525
# C1CCN[C@@H](C1)C(=O)O
# TMP00526 success.
# i= 526
# CCN=C(CC[C@@H](C(=O)O)N)O
# TMP00527 success.
# i= 527
# CCN=C(CC[C@@H](C(=O)O)N)O
# TMP00528 success.
# i= 528
# CCN=C(CC[C@@H](C(=O)O)N)O
# TMP00529 success.
# i= 529
# CCN=C(CC[C@@H](C(=O)O)N)O
# TMP00530 success.
# i= 530
# CCN=C(CC[C@@H](C(=O)O)N)O
# TMP00531 success.
# i= 531
# CCN=C(CC[C@@H](C(=O)O)N)O
# TMP00532 success.
# i= 532
# CC(=NCCCC[C@@H](C(=O)O)N)O
# TMP00533 success.
# i= 533
# CC(=NCCCC[C@@H](C(=O)O)N)O
# TMP00534 success.
# i= 534
# CC(=NCCCC[C@@H](C(=O)O)N)O
# TMP00535 success.
# i= 535
# CC(=NCCCC[C@@H](C(=O)O)N)O
# TMP00536 success.
# i= 536
# CC(=NCCCC[C@@H](C(=O)O)N)O
# TMP00537 success.
# i= 537
# CC(=NCCCC[C@@H](C(=O)O)N)O
# TMP00538 success.
# i= 538
# C[N+](C)(C)CCO
# TMP00539 success.
# i= 539
# C[N+](C)(C)CCO
# TMP00540 success.
# i= 540
# C[N+](C)(C)CCO
# TMP00541 success.
# i= 541
# C[N+](C)(C)CCO
# TMP00542 success.
# i= 542
# C[N+](C)(C)CCO
# TMP00543 success.
# i= 543
# C[N+](C)(C)CCO
# TMP00544 success.
# i= 544
# C([C@@H](C(=O)O)N)SS(=O)(=O)O
# TMP00545 success.
# i= 545
# C([C@@H](C(=O)O)N)SS(=O)(=O)O
# TMP00546 success.
# i= 546
# C([C@@H](C(=O)O)N)SS(=O)(=O)O
# TMP00547 success.
# i= 547
# C([C@@H](C(=O)O)N)SS(=O)(=O)O
# TMP00548 success.
# i= 548
# C([C@@H](C(=O)O)N)SS(=O)(=O)O
# TMP00549 success.
# i= 549
# C([C@@H](C(=O)O)N)SS(=O)(=O)O
# TMP00550 success.
# i= 550
# CN(C)CC(=O)O
# TMP00551 success.
# i= 551
# CN(C)CC(=O)O
# TMP00552 success.
# i= 552
# CN(C)CC(=O)O
# TMP00553 success.
# i= 553
# CN(C)CC(=O)O
# TMP00554 success.
# i= 554
# CN(C)CC(=O)O
# TMP00555 success.
# i= 555
# CN(C)CC(=O)O
# TMP00556 success.
# i= 556
# C1CCNC1
# TMP00557 success.
# i= 557
# C1CCNC1
# TMP00558 success.
# i= 558
# C1CCNC1
# TMP00559 success.
# i= 559
# C1CCNC1
# TMP00560 success.
# i= 560
# C1CCNC1
# TMP00561 success.
# i= 561
# C1CCNC1
# TMP00562 success.
# i= 562
# C[N+](C)(C)C[C@@H](CC(=O)[O-])O
# TMP00563 success.
# i= 563
# C[N+](C)(C)C[C@@H](CC(=O)[O-])O
# TMP00564 success.
# i= 564
# C[N+](C)(C)C[C@@H](CC(=O)[O-])O
# TMP00565 success.
# i= 565
# C[N+](C)(C)C[C@@H](CC(=O)[O-])O
# TMP00566 success.
# i= 566
# C[N+](C)(C)C[C@@H](CC(=O)[O-])O
# TMP00567 success.
# i= 567
# C[N+](C)(C)C[C@@H](CC(=O)[O-])O
# TMP00568 success.
# i= 568
# c1cc2c(cc1O)c(CCN)c[nH]2
# TMP00569 success.
# i= 569
# c1cc2c(cc1O)c(CCN)c[nH]2
# TMP00570 success.
# i= 570
# c1cc2c(cc1O)c(CCN)c[nH]2
# TMP00571 success.
# i= 571
# c1cc2c(cc1O)c(CCN)c[nH]2
# TMP00572 success.
# i= 572
# c1cc2c(cc1O)c(CCN)c[nH]2
# TMP00573 success.
# i= 573
# c1cc2c(cc1O)c(CCN)c[nH]2
# TMP00574 success.
# i= 574
# c1cn(CC(=O)O)cn1
# TMP00575 success.
# i= 575
# c1cn(CC(=O)O)cn1
# TMP00576 success.
# i= 576
# c1cn(CC(=O)O)cn1
# TMP00577 success.
# i= 577
# c1cn(CC(=O)O)cn1
# TMP00578 success.
# i= 578
# c1cn(CC(=O)O)cn1
# TMP00579 success.
# i= 579
# c1cn(CC(=O)O)cn1
# TMP00580 success.
# i= 580
# CC[C@@H](C(=NCC(=O)O)O)N=C(CC[C@@H](C(=O)O)N)O
# TMP00581 success.
# i= 581
# CC[C@@H](C(=NCC(=O)O)O)N=C(CC[C@@H](C(=O)O)N)O
# TMP00582 success.
# i= 582
# CC[C@@H](C(=NCC(=O)O)O)N=C(CC[C@@H](C(=O)O)N)O
# TMP00583 success.
# i= 583
# CC[C@@H](C(=NCC(=O)O)O)N=C(CC[C@@H](C(=O)O)N)O
# TMP00584 success.
# i= 584
# CC[C@@H](C(=NCC(=O)O)O)N=C(CC[C@@H](C(=O)O)N)O
# TMP00585 success.
# i= 585
# CC[C@@H](C(=NCC(=O)O)O)N=C(CC[C@@H](C(=O)O)N)O
# TMP00586 success.
# i= 586
# CN(CC(=O)O)C(=N)N
# TMP00587 success.
# i= 587
# CN(CC(=O)O)C(=N)N
# TMP00588 success.
# i= 588
# CN(CC(=O)O)C(=N)N
# TMP00589 success.
# i= 589
# CN(CC(=O)O)C(=N)N
# TMP00590 success.
# i= 590
# CN(CC(=O)O)C(=N)N
# TMP00591 success.
# i= 591
# CN(CC(=O)O)C(=N)N
# TMP00592 success.
# i= 592
# CS(=O)(=O)CCC(C(=O)O)N
# TMP00593 success.
# i= 593
# CS(=O)(=O)CCC(C(=O)O)N
# TMP00594 success.
# i= 594
# CS(=O)(=O)CCC(C(=O)O)N
# TMP00595 success.
# i= 595
# CS(=O)(=O)CCC(C(=O)O)N
# TMP00596 success.
# i= 596
# CS(=O)(=O)CCC(C(=O)O)N
# TMP00597 success.
# i= 597
# CS(=O)(=O)CCC(C(=O)O)N
# TMP00598 success.
# i= 598
# C(CC(=N[C@@H](CS)C(=NCC(=O)O)O)O)[C@@H](C(=O)O)N
# TMP00599 success.
# i= 599
# C(CC(=N[C@@H](CS)C(=NCC(=O)O)O)O)[C@@H](C(=O)O)N
# TMP00600 success.
# i= 600
# C(CC(=N[C@@H](CS)C(=NCC(=O)O)O)O)[C@@H](C(=O)O)N
# TMP00601 success.
# i= 601
# C(CC(=N[C@@H](CS)C(=NCC(=O)O)O)O)[C@@H](C(=O)O)N
# TMP00602 success.
# i= 602
# C(CC(=N[C@@H](CS)C(=NCC(=O)O)O)O)[C@@H](C(=O)O)N
# TMP00603 success.
# i= 603
# C(CC(=N[C@@H](CS)C(=NCC(=O)O)O)O)[C@@H](C(=O)O)N
# TMP00604 success.
# i= 604
# C1[C@H](CN[C@@H]1C(=O)O)O
# TMP00605 success.
# i= 605
# C1[C@H](CN[C@@H]1C(=O)O)O
# TMP00606 success.
# i= 606
# C1[C@H](CN[C@@H]1C(=O)O)O
# TMP00607 success.
# i= 607
# C1[C@H](CN[C@@H]1C(=O)O)O
# TMP00608 success.
# i= 608
# C1[C@H](CN[C@@H]1C(=O)O)O
# TMP00609 success.
# i= 609
# C1[C@H](CN[C@@H]1C(=O)O)O
# TMP00610 success.
# i= 610
# CC(=N[C@@H](Cc1cnc[nH]1)C(=O)O)O
# TMP00611 success.
# i= 611
# CC(=N[C@@H](Cc1cnc[nH]1)C(=O)O)O
# TMP00612 success.
# i= 612
# CC(=N[C@@H](Cc1cnc[nH]1)C(=O)O)O
# TMP00613 success.
# i= 613
# CC(=N[C@@H](Cc1cnc[nH]1)C(=O)O)O
# TMP00614 success.
# i= 614
# CC(=N[C@@H](Cc1cnc[nH]1)C(=O)O)O
# TMP00615 success.
# i= 615
# CC(=N[C@@H](Cc1cnc[nH]1)C(=O)O)O
# TMP00616 success.
# i= 616
# c1cc(c(cc1CCN)O)O
# TMP00617 success.
# i= 617
# c1cc(c(cc1CCN)O)O
# TMP00618 success.
# i= 618
# c1cc(c(cc1CCN)O)O
# TMP00619 success.
# i= 619
# c1cc(c(cc1CCN)O)O
# TMP00620 success.
# i= 620
# c1cc(c(cc1CCN)O)O
# TMP00621 success.
# i= 621
# c1cc(c(cc1CCN)O)O
# TMP00622 success.
# i= 622
# c1cc(ccc1N)O
# TMP00623 success.
# i= 623
# c1cc(ccc1N)O
# TMP00624 success.
# i= 624
# c1cc(ccc1N)O
# TMP00625 success.
# i= 625
# c1cc(ccc1N)O
# TMP00626 success.
# i= 626
# c1cc(ccc1N)O
# TMP00627 success.
# i= 627
# c1cc(ccc1N)O
# TMP00628 success.
# i= 628
# C(CCN)CC(=O)O
# TMP00629 success.
# i= 629
# C(CCN)CC(=O)O
# TMP00630 success.
# i= 630
# C(CCN)CC(=O)O
# TMP00631 success.
# i= 631
# C(CCN)CC(=O)O
# TMP00632 success.
# i= 632
# C(CCN)CC(=O)O
# TMP00633 success.
# i= 633
# C(CCN)CC(=O)O
# TMP00634 success.
# i= 634
# C(CC(=O)O)[C@@H](C(=O)O)N
# TMP00635 success.
# i= 635
# C(CC(=O)O)[C@@H](C(=O)O)N
# TMP00636 success.
# i= 636
# C(CC(=O)O)[C@@H](C(=O)O)N
# TMP00637 success.
# i= 637
# C(CC(=O)O)[C@@H](C(=O)O)N
# TMP00638 success.
# i= 638
# C(CC(=O)O)[C@@H](C(=O)O)N
# TMP00639 success.
# i= 639
# C(CC(=O)O)[C@@H](C(=O)O)N
# TMP00640 success.
# i= 640
# C[n+]1cccc(c1)C(=N)O
# TMP00641 success.
# i= 641
# C[n+]1cccc(c1)C(=N)O
# TMP00642 success.
# i= 642
# C[n+]1cccc(c1)C(=N)O
# TMP00643 success.
# i= 643
# C[n+]1cccc(c1)C(=N)O
# TMP00644 success.
# i= 644
# C[n+]1cccc(c1)C(=N)O
# TMP00645 success.
# i= 645
# C[n+]1cccc(c1)C(=N)O
# TMP00646 success.
# i= 646
# C(CC(=O)O)CN
# TMP00647 success.
# i= 647
# C(CC(=O)O)CN
# TMP00648 success.
# i= 648
# C(CC(=O)O)CN
# TMP00649 success.
# i= 649
# C(CC(=O)O)CN
# TMP00650 success.
# i= 650
# C(CC(=O)O)CN
# TMP00651 success.
# i= 651
# C(CC(=O)O)CN
# TMP00652 success.
# i= 652
# C[C@H]([C@@H](C(=O)O)N)O
# TMP00653 success.
# i= 653
# C[C@H]([C@@H](C(=O)O)N)O
# TMP00654 success.
# i= 654
# C[C@H]([C@@H](C(=O)O)N)O
# TMP00655 success.
# i= 655
# C[C@H]([C@@H](C(=O)O)N)O
# TMP00656 success.
# i= 656
# C[C@H]([C@@H](C(=O)O)N)O
# TMP00657 success.
# i= 657
# C[C@H]([C@@H](C(=O)O)N)O
# TMP00658 success.
# i= 658
# CC(=N[C@@H](CCCNC(=N)N)C(=O)O)O
# TMP00659 success.
# i= 659
# CC(=N[C@@H](CCCNC(=N)N)C(=O)O)O
# TMP00660 success.
# i= 660
# CC(=N[C@@H](CCCNC(=N)N)C(=O)O)O
# TMP00661 success.
# i= 661
# CC(=N[C@@H](CCCNC(=N)N)C(=O)O)O
# TMP00662 success.
# i= 662
# CC(=N[C@@H](CCCNC(=N)N)C(=O)O)O
# TMP00663 success.
# i= 663
# CC(=N[C@@H](CCCNC(=N)N)C(=O)O)O
# TMP00664 success.
# i= 664
# C([C@@H](C(=O)O)N)C(=O)O
# TMP00665 success.
# i= 665
# C([C@@H](C(=O)O)N)C(=O)O
# TMP00666 success.
# i= 666
# C([C@@H](C(=O)O)N)C(=O)O
# TMP00667 success.
# i= 667
# C([C@@H](C(=O)O)N)C(=O)O
# TMP00668 success.
# i= 668
# C([C@@H](C(=O)O)N)C(=O)O
# TMP00669 success.
# i= 669
# C([C@@H](C(=O)O)N)C(=O)O
# TMP00670 success.
# i= 670
# CC(=N[C@@H](CCCCN)C(=O)O)O
# TMP00671 success.
# i= 671
# CC(=N[C@@H](CCCCN)C(=O)O)O
# TMP00672 success.
# i= 672
# CC(=N[C@@H](CCCCN)C(=O)O)O
# TMP00673 success.
# i= 673
# CC(=N[C@@H](CCCCN)C(=O)O)O
# TMP00674 success.
# i= 674
# CC(=N[C@@H](CCCCN)C(=O)O)O
# TMP00675 success.
# i= 675
# CC(=N[C@@H](CCCCN)C(=O)O)O
# TMP00676 success.
# i= 676
# CC(=NCCC(=N[C@@H](Cc1cnc[nH]1)C(=O)O)O)O
# TMP00677 success.
# i= 677
# CC(=NCCC(=N[C@@H](Cc1cnc[nH]1)C(=O)O)O)O
# TMP00678 success.
# i= 678
# CC(=NCCC(=N[C@@H](Cc1cnc[nH]1)C(=O)O)O)O
# TMP00679 success.
# i= 679
# CC(=NCCC(=N[C@@H](Cc1cnc[nH]1)C(=O)O)O)O
# TMP00680 success.
# i= 680
# CC(=NCCC(=N[C@@H](Cc1cnc[nH]1)C(=O)O)O)O
# TMP00681 success.
# i= 681
# CC(=NCCC(=N[C@@H](Cc1cnc[nH]1)C(=O)O)O)O
# TMP00682 success.
# i= 682
# C(C(=O)O)NC(=N)N
# TMP00683 success.
# i= 683
# C(C(=O)O)NC(=N)N
# TMP00684 success.
# i= 684
# C(C(=O)O)NC(=N)N
# TMP00685 success.
# i= 685
# C(C(=O)O)NC(=N)N
# TMP00686 success.
# i= 686
# C(C(=O)O)NC(=N)N
# TMP00687 success.
# i= 687
# C(C(=O)O)NC(=N)N
# TMP00688 success.
# i= 688
# CS(=O)CCC(C(=O)O)N
# TMP00689 success.
# i= 689
# CS(=O)CCC(C(=O)O)N
# TMP00690 success.
# i= 690
# CS(=O)CCC(C(=O)O)N
# TMP00691 success.
# i= 691
# CS(=O)CCC(C(=O)O)N
# TMP00692 success.
# i= 692
# CS(=O)CCC(C(=O)O)N
# TMP00693 success.
# i= 693
# CS(=O)CCC(C(=O)O)N
# TMP00694 success.
# i= 694
# c1cnc([nH]c1=N)O
# TMP00695 success.
# i= 695
# c1cnc([nH]c1=N)O
# TMP00696 success.
# i= 696
# c1cnc([nH]c1=N)O
# TMP00697 success.
# i= 697
# c1cnc([nH]c1=N)O
# TMP00698 success.
# i= 698
# c1cnc([nH]c1=N)O
# TMP00699 success.
# i= 699
# c1cnc([nH]c1=N)O
# TMP00700 success.
# i= 700
# CC(=N[C@@H](CCCN)C(=O)O)O
# TMP00701 success.
# i= 701
# CC(=N[C@@H](CCCN)C(=O)O)O
# TMP00702 success.
# i= 702
# CC(=N[C@@H](CCCN)C(=O)O)O
# TMP00703 success.
# i= 703
# CC(=N[C@@H](CCCN)C(=O)O)O
# TMP00704 success.
# i= 704
# CC(=N[C@@H](CCCN)C(=O)O)O
# TMP00705 success.
# i= 705
# CC(=N[C@@H](CCCN)C(=O)O)O
# TMP00706 success.
# i= 706
# C([C@@H](C(=O)O)N)O
# TMP00707 success.
# i= 707
# C([C@@H](C(=O)O)N)O
# TMP00708 success.
# i= 708
# C([C@@H](C(=O)O)N)O
# TMP00709 success.
# i= 709
# C([C@@H](C(=O)O)N)O
# TMP00710 success.
# i= 710
# C([C@@H](C(=O)O)N)O
# TMP00711 success.
# i= 711
# C([C@@H](C(=O)O)N)O
# TMP00712 success.
# i= 712
# CN1CC(=NC1=N)O
# TMP00713 success.
# i= 713
# CN1CC(=NC1=N)O
# TMP00714 success.
# i= 714
# CN1CC(=NC1=N)O
# TMP00715 success.
# i= 715
# CN1CC(=NC1=N)O
# TMP00716 success.
# i= 716
# CN1CC(=NC1=N)O
# TMP00717 success.
# i= 717
# CN1CC(=NC1=N)O
# TMP00718 success.
# i= 718
# c1cn([C@H]2[C@@H]([C@@H]([C@@H](CO)O2)O)O)c(nc1=N)O
# TMP00719 success.
# i= 719
# c1cn([C@H]2[C@@H]([C@@H]([C@@H](CO)O2)O)O)c(nc1=N)O
# TMP00720 success.
# i= 720
# c1cn([C@H]2[C@@H]([C@@H]([C@@H](CO)O2)O)O)c(nc1=N)O
# TMP00721 success.
# i= 721
# c1cn([C@H]2[C@@H]([C@@H]([C@@H](CO)O2)O)O)c(nc1=N)O
# TMP00722 success.
# i= 722
# c1cn([C@H]2[C@@H]([C@@H]([C@@H](CO)O2)O)O)c(nc1=N)O
# TMP00723 success.
# i= 723
# c1cn([C@H]2[C@@H]([C@@H]([C@@H](CO)O2)O)O)c(nc1=N)O
# TMP00724 success.
# i= 724
# C(CO)NCCO
# TMP00725 success.
# i= 725
# C(CO)NCCO
# TMP00726 success.
# i= 726
# C(CO)NCCO
# TMP00727 success.
# i= 727
# C(CN)c1cnc[nH]1
# TMP00728 success.
# i= 728
# C(CN)c1cnc[nH]1
# TMP00729 success.
# i= 729
# C(CN)c1cnc[nH]1
# TMP00730 success.
# i= 730
# C(CS)C(C(=O)O)N
# TMP00731 success.
# i= 731
# C(CS)C(C(=O)O)N
# TMP00732 success.
# i= 732
# C(CS)C(C(=O)O)N
# TMP00733 success.
# i= 733
# C(C[C@@H](C(=O)O)N)CNC(=N)N[C@@H](CC(=O)O)C(=O)O
# TMP00734 success.
# i= 734
# C(C[C@@H](C(=O)O)N)CNC(=N)N[C@@H](CC(=O)O)C(=O)O
# TMP00735 success.
# i= 735
# C(C[C@@H](C(=O)O)N)CNC(=N)N[C@@H](CC(=O)O)C(=O)O
# TMP00736 success.
# i= 736
# CC(C)[C@@H](C(=O)O)N
# TMP00737 success.
# i= 737
# CC(C)[C@@H](C(=O)O)N
# TMP00738 success.
# i= 738
# CC(C)[C@@H](C(=O)O)N
# TMP00739 success.
# i= 739
# C(CC(=N[C@@H](CS)C(=O)O)O)[C@@H](C(=O)O)N
# TMP00740 success.
# i= 740
# C(CC(=N[C@@H](CS)C(=O)O)O)[C@@H](C(=O)O)N
# TMP00741 success.
# i= 741
# C(CC(=N[C@@H](CS)C(=O)O)O)[C@@H](C(=O)O)N
# TMP00742 success.
# i= 742
# c1ccc(c(c1)C(=O)O)C(=O)O
# TMP00743 success.
# i= 743
# c1ccc(c(c1)C(=O)O)C(=O)O
# TMP00744 success.
# i= 744
# c1ccc(c(c1)C(=O)O)C(=O)O
# TMP00745 success.
# i= 745
# C(CC(=N[C@@H](CSSC[C@@H](C(=NCC(=O)O)O)N=C(CC[C@@H](C(=O)O)N)O)C(=NCC(=O)O)O)O)[C@@H](C(=O)O)N
# TMP00746 success.
# i= 746
# C(CC(=N[C@@H](CSSC[C@@H](C(=NCC(=O)O)O)N=C(CC[C@@H](C(=O)O)N)O)C(=NCC(=O)O)O)O)[C@@H](C(=O)O)N
# TMP00747 success.
# i= 747
# C(CC(=N[C@@H](CSSC[C@@H](C(=NCC(=O)O)O)N=C(CC[C@@H](C(=O)O)N)O)C(=NCC(=O)O)O)O)[C@@H](C(=O)O)N
# TMP00748 success.
# i= 748
# COC(=O)c1cccnc1
# TMP00749 success.
# i= 749
# COC(=O)c1cccnc1
# TMP00750 success.
# i= 750
# COC(=O)c1cccnc1
# TMP00751 success.
# i= 751
# COC(=O)c1cccnc1
# TMP00752 success.
# i= 752
# COC(=O)c1cccnc1
# TMP00753 success.
# i= 753
# COC(=O)c1cccnc1
# TMP00754 success.
# i= 754
# c1cc(ccc1C(=O)O)N
# TMP00755 success.
# i= 755
# c1cc(ccc1C(=O)O)N
# TMP00756 success.
# i= 756
# c1cc(ccc1C(=O)O)N
# TMP00757 success.
# i= 757
# c1cc(ccc1C(=O)O)N
# TMP00758 success.
# i= 758
# c1cc(ccc1C(=O)O)N
# TMP00759 success.
# i= 759
# c1cc(ccc1C(=O)O)N
# TMP00760 success.
# i= 760
# Cn1cnc2c1c(=O)n(C)c(n2)O
# TMP00761 success.
# i= 761
# Cn1cnc2c1c(=O)n(C)c(n2)O
# TMP00762 success.
# i= 762
# Cn1cnc2c1c(=O)n(C)c(n2)O
# TMP00763 success.
# i= 763
# Cn1cnc2c1c(=O)n(C)c(n2)O
# TMP00764 success.
# i= 764
# Cn1cnc2c1c(=O)n(C)c(n2)O
# TMP00765 success.
# i= 765
# Cn1cnc2c1c(=O)n(C)c(n2)O
# TMP00766 success.
# i= 766
# C1CN(CCN1CCO)CCS(=O)(=O)O
# TMP00767 success.
# i= 767
# C1CN(CCN1CCO)CCS(=O)(=O)O
# TMP00768 success.
# i= 768
# C1CN(CCN1CCO)CCS(=O)(=O)O
# TMP00769 success.
# i= 769
# C1CN(CCN1CCO)CCS(=O)(=O)O
# TMP00770 success.
# i= 770
# C1CN(CCN1CCO)CCS(=O)(=O)O
# TMP00771 success.
# i= 771
# C1CN(CCN1CCO)CCS(=O)(=O)O
# TMP00772 success.
# i= 772
# C(CC(C(=O)O)N)CC(C(=O)O)N
# TMP00773 success.
# i= 773
# C(CC(C(=O)O)N)CC(C(=O)O)N
# TMP00774 success.
# i= 774
# C(CC(C(=O)O)N)CC(C(=O)O)N
# TMP00775 success.
# i= 775
# C(CC(C(=O)O)N)CC(C(=O)O)N
# TMP00776 success.
# i= 776
# C(CC(C(=O)O)N)CC(C(=O)O)N
# TMP00777 success.
# i= 777
# C(CC(C(=O)O)N)CC(C(=O)O)N
# TMP00778 success.
# i= 778
# c1cc(cc(c1)N)C(=O)O
# TMP00779 success.
# i= 779
# c1cc(cc(c1)N)C(=O)O
# TMP00780 success.
# i= 780
# c1cc(cc(c1)N)C(=O)O
# TMP00781 success.
# i= 781
# c1cc(cc(c1)N)C(=O)O
# TMP00782 success.
# i= 782
# c1cc(cc(c1)N)C(=O)O
# TMP00783 success.
# i= 783
# c1cc(cc(c1)N)C(=O)O
# TMP00784 success.
# i= 784
# CC(=N[C@@H](CCCNC(=N)O)C(=O)O)O
# TMP00785 success.
# i= 785
# CC(=N[C@@H](CCCNC(=N)O)C(=O)O)O
# TMP00786 success.
# i= 786
# CC(=N[C@@H](CCCNC(=N)O)C(=O)O)O
# TMP00787 success.
# i= 787
# CC(=N[C@@H](CCCNC(=N)O)C(=O)O)O
# TMP00788 success.
# i= 788
# CC(=N[C@@H](CCCNC(=N)O)C(=O)O)O
# TMP00789 success.
# i= 789
# CC(=N[C@@H](CCCNC(=N)O)C(=O)O)O
# TMP00790 success.
# i= 790
# c1cc(CC(=O)O)cnc1
# TMP00791 success.
# i= 791
# c1cc(CC(=O)O)cnc1
# TMP00792 success.
# i= 792
# c1cc(CC(=O)O)cnc1
# TMP00793 success.
# i= 793
# c1cc(CC(=O)O)cnc1
# TMP00794 success.
# i= 794
# c1cc(CC(=O)O)cnc1
# TMP00795 success.
# i= 795
# c1cc(CC(=O)O)cnc1
# TMP00796 success.
# i= 796
# C1CN(CCN1CCS(=O)(=O)O)CCS(=O)(=O)O
# TMP00797 success.
# i= 797
# C1CN(CCN1CCS(=O)(=O)O)CCS(=O)(=O)O
# TMP00798 success.
# i= 798
# C1CN(CCN1CCS(=O)(=O)O)CCS(=O)(=O)O
# TMP00799 success.
# i= 799
# C1CN(CCN1CCS(=O)(=O)O)CCS(=O)(=O)O
# TMP00800 success.
# i= 800
# C1CN(CCN1CCS(=O)(=O)O)CCS(=O)(=O)O
# TMP00801 success.
# i= 801
# C1CN(CCN1CCS(=O)(=O)O)CCS(=O)(=O)O
# TMP00802 success.
# i= 802
# COc1cc(ccc1O)/C=C/C(=O)O
# TMP00803 success.
# i= 803
# COc1cc(ccc1O)/C=C/C(=O)O
# TMP00804 success.
# i= 804
# COc1cc(ccc1O)/C=C/C(=O)O
# TMP00805 success.
# i= 805
# COc1cc(ccc1O)/C=C/C(=O)O
# TMP00806 success.
# i= 806
# COc1cc(ccc1O)/C=C/C(=O)O
# TMP00807 success.
# i= 807
# COc1cc(ccc1O)/C=C/C(=O)O
# TMP00808 success.
# i= 808
# COC(=O)[C@H](Cc1ccccc1)N=C([C@H](CC(=O)O)N)O
# TMP00809 success.
# i= 809
# COC(=O)[C@H](Cc1ccccc1)N=C([C@H](CC(=O)O)N)O
# TMP00810 success.
# i= 810
# COC(=O)[C@H](Cc1ccccc1)N=C([C@H](CC(=O)O)N)O
# TMP00811 success.
# i= 811
# COC(=O)[C@H](Cc1ccccc1)N=C([C@H](CC(=O)O)N)O
# TMP00812 success.
# i= 812
# COC(=O)[C@H](Cc1ccccc1)N=C([C@H](CC(=O)O)N)O
# TMP00813 success.
# 2.85052490234375

# %%
smilelist = set(smilelist)
print(len(smilelist))
print(smilelist)
# Out:
# 139
# {'CSCC[C@@H](C(=O)O)N', 'C(CCN)CC(=O)O', 'C[N+](C)(C)CC(=O)[O-]', 'C[N+]1(C)CCC[C@H]1C(=O)[O-]', 'c1ccc2c(c1)c(c[nH]2)C(=O)O', 'c1ccc2c(c1)nc(O)o2', 'CC(C)[C@@H](C(=O)O)N', 'c1ccc(c(c1)N)O', 'c1cn([C@H]2[C@@H]([C@@H]([C@@H](CO)O2)O)O)c(=O)nc1O', 'c1ccc(c(c1)C(=NCC(=O)O)O)O', 'CC[C@H](C)[C@@H](C(=O)O)N', 'C1CCN[C@@H](C1)C(=O)O', 'c1cc(cnc1)C(=N)O', 'c1cc2c(cc1O)c(CCN)c[nH]2', 'CN(=O)(C)C', 'CC(=N[C@@H]1[C@H](C[C@](C(=O)O)(O)O[C@H]1[C@@H]([C@@H](CO)O)O)O)O', 'c1nc2c([nH]1)[nH]c(=N)nc2O', 'C[n+]1cccc(c1)C(=O)[O-]', 'C(CC(=N[C@@H](CS)C(=NCC(=O)O)O)O)[C@@H](C(=O)O)N', 'C1CCC(CC1)NCCS(=O)(=O)O', 'Cc1cnc(nc1O)O', 'C1CN(CCN1CCO)CCS(=O)(=O)O', 'CC(=N[C@@H](Cc1cnc[nH]1)C(=O)O)O', 'CC(=N[C@@H](CCCN)C(=O)O)O', 'CCCCC(C(=O)O)N', 'C[N+](C)(C)CCCC(=O)[O-]', 'c1ccc2c(c1)ccc(C(=O)O)n2', 'CC(=N[C@@H](CCCCN)C(=O)O)O', 'C(C[C@@H](C(=O)O)N)CNC(=N)N[C@@H](CC(=O)O)C(=O)O', 'CC(CCC(=O)[O-])[N+](C)(C)C', 'c1ccc(cc1)C(=NCC(=O)O)O', 'C1[C@H](CN[C@@H]1C(=O)O)O', 'CCN=C(CC[C@@H](C(=O)O)N)O', 'c1cc(c(cc1CCN)O)O', 'c1cc(cnc1)O', 'CC(=N[C@@H](CCCNC(=N)O)C(=O)O)O', 'C[N+](C)(C)CCCCC(=O)[O-]', 'CC(=O)c1cnccn1', 'c1nc2c([nH]1)ncnc2O', 'CC(C(=O)[O-])[N+](C)(C)C', 'C([C@@H](C(=O)O)N)C(=O)O', 'C[N+](C)(C)[C@@H](Cc1c[nH]c2ccccc12)C(=O)[O-]', 'CC(=NCCCC[C@@H](C(=O)O)N)O', 'C(C(=O)O)NC(=N)N', 'C[C@H]([C@@H](C(=O)O)N)O', 'CN=C(c1cccnc1)O', 'c1cc(cc(c1)N)C(=O)O', 'c1ccnc(c1)CC(=O)O', 'COC(=O)c1cccnc1', 'CC1CCCN1', 'Cn1cncc1C[C@@H](C(=O)O)N=C(CCN)O', 'c1cc(ccc1C[C@@H](C(=O)O)N)O', 'C[N+](C)(C)[C@@H](Cc1ccccc1)C(=O)[O-]', 'C([C@@H]1[C@H]([C@H]([C@H](n2cnc3c(N)ncnc23)O1)O)O)O', 'Cn1cnc2c1c(=O)n(C)c(n2)O', 'C(CS)C(C(=O)O)N', 'CC(=N[C@@H](CC(=O)O)C(=O)O)O', 'c1cc(c(nc1)O)O', 'C([C@@H](C(=O)O)N)SS(=O)(=O)O', 'c1ccc(c(c1)C(=O)O)C(=O)O', 'C1CCN(CC1)C(=O)/C=C/C=C/c1ccc2c(c1)OCO2', 'COC(=O)[C@H](Cc1ccccc1)N=C([C@H](CC(=O)O)N)O', 'C(CC(=O)O)CNC(=N)N', 'c1cn(CC(=O)O)cn1', 'C1CCN=C(C1)O', 'CN1CCCN=C1/C=C/c1cccs1', 'c1ccc2c(c1)c(CC(=O)O)c[nH]2', 'c12c([nH]c(n2)O)nc(nc1O)O', 'CN(CC(=O)O)C(=N)N', 'c1cc(c(cc1N)O)C(=O)O', 'c1ccc(cc1)C[C@@H](C(=O)O)N', 'C(CN)c1cnc[nH]1', 'CN1CC(=NC1=N)O', 'C(CC(=O)O)CN', 'c1ccc(c(c1)C(=O)O)N', 'C[n+]1cccc(c1)C(=N)O', 'c1nc2c(N)nc[nH]c2n1', 'CC(=NCCC(=N[C@@H](Cc1cnc[nH]1)C(=O)O)O)O', 'C1(C(=NC(=N1)O)O)NC(=N)O', 'C([C@@H]1[C@H]([C@H]([C@H](n2cnc3c2[nH]c(=N)nc3O)O1)O)O)O', 'C(CC(=O)O)[C@@H](C(=O)O)N', 'C[N+]1(C)CCCC[C@H]1C(=O)[O-]', 'c1cnc([nH]c1=N)O', 'CC(C)(CO)C(C(=NCCC(=O)O)O)O', 'c1cc(ccc1N)O', 'C(C[C@@H](C(=O)O)N)CNC(=N)N', 'C[C@H](CCC(=NCC(=O)O)O)[C@H]1CC[C@H]2[C@H]3[C@H](C[C@@H]([C@]12C)O)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O', 'CN1CCC[C@H]1C(=O)O', 'COC(=O)c1c(N)nccn1', 'C[C@H](CCC(=NCCS(=O)(=O)O)O)[C@H]1CC[C@H]2[C@H]3[C@H](C[C@@H]([C@]12C)O)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O', 'C(CC(=N[C@@H](CS)C(=O)O)O)[C@@H](C(=O)O)N', 'CC(=N[C@@H]1[C@H]([C@@H]([C@@H](CO)OC1O)O)O)O', 'Cn1cnc2c1c(=O)n(C)c(=O)n2C', 'C([C@@H](C(=O)O)N)O', 'CN(C)C(=N)NCCC[C@@H](C(=O)O)N', 'C(c1cnc[nH]1)[C@@H](C(=O)O)N', 'CN(C)CC(=O)O', 'CC(=O)OCC[N+](C)(C)C', 'C1CCNC1', 'c1cc(CC(=O)O)cnc1', 'C(CC(C(=O)O)N)CC(C(=O)O)N', 'Cn1c(=O)c2c([nH]cn2)nc1O', 'c1cn([C@H]2[C@@H]([C@@H]([C@@H](CO)O2)O)O)c(nc1=N)O', 'C1CN(CCN1CCS(=O)(=O)O)CCS(=O)(=O)O', 'Cn1cnc2c1c(nc(=O)n2C)O', 'c1ccc2c(c1)c(C[C@@H](C(=O)O)N)c[nH]2', 'c1cnc(nc1O)O', 'C[N+](C)(C)CCO', 'c1cc(cnc1)C(=O)O', 'c1cc(ccc1C(=O)O)N', 'C(COCCOCCOCCOCCOCCO)O', 'C[C@H](CCC(=O)O)[C@H]1CC[C@H]2[C@H]3[C@H](CC[C@]12C)[C@@]1(C)CC[C@H](C[C@H]1C[C@H]3O)O', 'C1COCCN1CCS(=O)(=O)O', 'C([C@@H]1[C@H]([C@H]([C@H](n2cnc3c2ncnc3O)O1)O)O)O', 'C(CC(=N[C@@H](CSSC[C@@H](C(=NCC(=O)O)O)N=C(CC[C@@H](C(=O)O)N)O)C(=NCC(=O)O)O)O)[C@@H](C(=O)O)N', 'CS(=O)CCC(C(=O)O)N', 'CS(=O)(=O)CCC(C(=O)O)N', 'c1ccc2c(c1)c(=O)cc(C(=O)O)[nH]2', 'c1nc2c([nH]1)nc(nc2O)O', 'COc1cc(ccc1O)/C=C/C(=O)O', 'CC(C)C(C(=O)[O-])[N+](C)(C)C', 'c1ccc(cc1)/C=C/C(=NCC(=O)O)O', 'Cn1c2c(c(=O)n(C)c1=O)nc[nH]2', 'CC(=N[C@@H](CCCNC(=N)N)C(=O)O)O', 'CC(C)C[C@@H](C(=O)O)N', 'CC1(C)[C@H](C(=O)O)N2C(=O)[C@H]([C@H]2S1)N=C([C@@H](c1ccc(cc1)O)N)O', 'C1C[C@@H](C(=O)O)NC1', 'CCCCOP(=O)(OCCCC)OCCCC', 'CCCC(C(=O)[O-])[N+ ...

# %%
print(len(classlist))
classlist["InChIKey=RDHQFKQIGNGIED-UHFFFAOYSA-N"]
# Out:
# 139
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-aa4d49a3e09b> in <module>
#       1 print(len(classlist))
# ----> 2 classlist["InChIKey=RDHQFKQIGNGIED-UHFFFAOYSA-N"]
#
# KeyError: 'InChIKey=RDHQFKQIGNGIED-UHFFFAOYSA-N'

# %%
classlist
# Out:
# {'InChIKey=TUHVEAJXIMEOSA-UHFFFAOYSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=DRTQHJPVMGBUCF-XVFCMESISA-N': 'Pyrimidine nucleosides',
#  'InChIKey=JJMDCOVWQOJGCB-UHFFFAOYSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=ONIBWKKTOPOVIA-BYPYZUCNSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=YSAUAVHXTIETRK-AATRIKPKSA-N': 'Pyrimidines and pyrimidine derivatives',
#  'InChIKey=RXHVPPWXTMHWGY-UHFFFAOYSA-N': 'Fatty acids and conjugates',
#  'InChIKey=MXXWOMGUGJBKIW-YPCIICBESA-N': 'Alkaloids and derivatives',
#  'InChIKey=LSQZJLSUYDQPKJ-NJBDSQKTSA-N': 'Beta lactams',
#  'InChIKey=CMUNUTVVOOHQPW-LURJTMIESA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=BPMFZUMJYQTVII-UHFFFAOYSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=KWIUHFFTVRNATP-UHFFFAOYSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=AOHCBEAZXHZMOR-ZDUSSCGKSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=WJXSWCUQABXPFS-UHFFFAOYSA-N': 'Benzoic acids and derivatives',
#  'InChIKey=MYYIAHXIVFADCU-QMMMGPOBSA-N': 'Hybrid peptides',
#  'InChIKey=SQVRNKJHWKZAKO-PFQGKNLYSA-N': 'Carbohydrates and carbohydrate conjugates',
#  'InChIKey=OPTASPLRGRRNAP-UHFFFAOYSA-N': 'Pyrimidines and pyrimidine derivatives',
#  'InChIKey=JKMHFZQWWAIEOD-UHFFFAOYSA-N': 'Piperazines',
#  'InChIKey=OTCCIMWXFLJLIA-BYPYZUCNSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=PVNIIMVLHYAWGP-UHFFFAOYSA-N': 'Pyridinecarboxylic acids and derivatives',
#  'InChIKey=DBZAKQWXICEWNW-UHFFFAOYSA-N': 'Carbonyl compounds',
#  'InChIKey=QIVBCDIJIAJPQS-VIFPVBQESA-N': 'Indolyl carboxylic acids and derivatives',
#  'InChIKey=OEYIOHPDSNJKLS-UHFFFAOYSA-N': 'Quaternary ammonium salts',
#  'InChIKey=KZSNJWFQEVHDMF-BYPYZUCNSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=PMMYEEVYMWASQN-DMTCNVIQSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=ASSKVPFEZFQQNQ-UHFFFAOYSA-N': 'Benzoxazolones',
#  'InChIKey=ODHCTXKNWHHXJC-VKHMYHEASA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=BTCSSZJGUNDROE-UHFFFAOYSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=RZVAJINKPMORJF-UHFFFAOYSA-N': '1-hydroxy-2-unsubstituted benzenoids',
#  'InChIKey=GRFNBEZIAWKNCO-UHFFFAOYSA-N': 'Hydroxypyridines',
#  'InChIKey=UHDGCWIWMRVCDJ-XVFCMESISA-N': 'Pyrimidine nucleosides',
#  'InChIKey=SEOVTRFCIGRIMH-UHFFFAOYSA-N': 'Indolyl carboxylic acids and derivatives',
#  'InChIKey=RWQNBRDOKXIBIV-UHFFFAOYSA-N': 'Pyrimidines and pyrimidine derivatives',
#  'InChIKey=WUBBRNOQWQTFEX-UHFFFAOYSA-N': 'Benzoic acids and derivatives',
#  'InChIKey=WMQMIOYQXNRROC-LURJTMIESA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=COLNVLDHVKWLRT-QMMMGPOBSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=OIRDTQYFTABQOQ-KQYNXXCUSA-N': 'Purine nucleosides',
#  'InChIKey=HNDVDQJCIGZPNO-YFKPBYRVSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=LRFVTYWOQMYALW-UHFFFAOYSA-N': 'Purines and purine derivatives',
#  'InChIKey=NOKPBJYHPHHWAN-REOHCLBHSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=SXGZJKUKBWWHRA-UHFFFAOYSA-N': 'Morpholines',
#  'InChIKey=KBOJOGQFRVVWBH-ZETCQYMHSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=XFDUHJPVQKIXHO-UHFFFAOYSA-N': 'Benzoic acids and derivatives',
#  'InChIKey=FFEARJCKVFRZRR-BYPYZUCNSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=JRLGPAXAGHMNOL-LURJTMIESA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=GHOKWGTUZJEAQD-UHFFFAOYSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=QEFRNWWLZKMPFJ-UHFFFAOYSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=PHIQHXFUZVPYII-ZCFIWIBFSA-N': 'Quaternary ammonium salts',
#  'InChIKey=WHUUTDBJXJRKMK-VKHMYHEASA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=UGQMRVRMYYASKQ-KQYNXXCUSA-N': 'Purine nucleosides',
#  'InChIKey=RFDAIACWWDREDC-FRVQLJSFSA-N': 'Bile acids, alcohols and derivatives',
#  'InChIKey=REWYJJRDEOKNBQ-UHFFFAOYSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=HXEACLLIILLPRG-YFKPBYRVSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=OIPILFWXSMYKGL-UHFFFAOYSA-N': 'Quaternary ammonium salts',
#  'InChIKey=CVSVTCORWBXHQV-UHFFFAOYSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=YDGMGEXADBMOMJ-LURJTMIESA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=KSEBMYQBYZTDHS-HWKANZROSA-N': 'Hydroxycinnamic acids and derivatives',
#  'InChIKey=RWRDLPDLKQPQOW-UHFFFAOYSA-N': 'Pyrrolidines',
#  'InChIKey=RWSXRVCMGQZWBV-WDSKDSINSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=SNEIUMQYRCDYCH-LURJTMIESA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=WWNNZCOKKKDOPX-UHFFFAOYSA-N': 'Alkaloids and derivatives',
#  'InChIKey=JHPNVNIEXXLNTR-UHFFFAOYSA-N': 'Fatty acids and conjugates',
#  'InChIKey=INCSQLZZXBPATR-UHFFFAOYSA-N': 'Pyrazines',
#  'InChIKey=MVOYJPOZRLFTCP-UHFFFAOYSA-N': 'Purines and purine derivatives',
#  'InChIKey=RWZYAGGXGHYGMB-UHFFFAOYSA-N': 'Benzoic acids and derivatives',
#  'InChIKey=RGHPCLZJAFCTIK-UHFFFAOYSA-N': 'Pyrrolidines',
#  'InChIKey=LDHMAVIPBRSVRG-UHFFFAOYSA-O': 'Pyridinecarboxylic acids and derivatives',
#  'InChIKey=ZFXYFBGIUFBOJW-UHFFFAOYSA-N': 'Purines and purine derivatives',
#  'InChIKey=WGNUNYPERJMVRM-UHFFFAOYSA-N': 'Pyridines and derivatives',
#  'InChIKey=BPSNETAIJADFTO-UHFFFAOYSA-N': 'Pyridines and derivatives',
#  'InChIKey=AYFVYJQAPQTCCC-GBXIJSLDSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=CDAWCLOXVUBKRW-UHFFFAOYSA-N': 'Aniline and substituted anilines',
#  'InChIKey=YPZRWBKMTBYPTK-BJDJZHNGSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=QIAFMBKCNZACKA-UHFFFAOYSA-N': 'Benzoic acids and derivatives',
#  'InChIKey=IHPYMWDTONKSCO-UHFFFAOYSA-N': 'Piperazines',
#  'InChIKey=UYTPUPDQBNUYGX-UHFFFAOYSA-N': 'Purines and purine derivatives',
#  'InChIKey=DTERQYGMUDWYAZ-ZETCQYMHSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=VCKPUUFAIGNJHC-UHFFFAOYSA-N': 'Carbonyl compounds',
#  'InChIKey=LEHOTFFKMJEONL-UHFFFAOYSA-N': 'Purines and purine derivatives',
#  'InChIKey=ROHFNLRQFUQHCH-YFKPBYRVSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=GFFGJBXGBJISGV-UHFFFAOYSA-N': 'Purines and purine derivatives',
#  'InChIKey=HCZHHEIFKROPDY-UHFFFAOYSA-N': 'Quinoline carboxylic acids',
#  'InChIKey=ISAKRJDGNUQOIC-UHFFFAOYSA-N': 'Pyrimidines and pyrimidine derivatives',
#  'InChIKey=XUWHAWMETYGRKB-UHFFFAOYSA-N': 'Piperidinones',
#  'InChIKey=UYPYRKYUKCHHIB-UHFFFAOYSA-N': 'Aminoxides',
#  'InChIKey=STCOOQWBFONSKY-UHFFFAOYSA-N': 'Phosphate esters',
#  'InChIKey=DFPAKSUCGFBDDF-UHFFFAOYSA-N': 'Pyridinecarboxylic acids and derivatives',
#  'InChIKey=KDZOASGQNOPSCU-WDSKDSINSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=GMKMEZVLHJARHF-UHFFFAOYSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=CKLJMWTZIZZHCS-REOHCLBHSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=IIRDTKBZINWQAW-UHFFFAOYSA-N': 'Ethers',
#  'InChIKey=XNGIFLGASWRNHJ-UHFFFAOYSA-N': 'Benzoic acids and derivatives',
#  'InChIKey=FDGQSTZJBFJUBT-UHFFFAOYSA-N': 'Purines and purine derivatives',
#  'InChIKey=YNBADRVTZLEFNH-UHFFFAOYSA-N': 'Pyridinecarboxylic acids and derivatives',
#  'InChIKey=FFFHZYDWPBMWHY-UHFFFAOYSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=UCUNFLYVYCGDHP-UHFFFAOYSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=NTYJJOPFIAHURM-UHFFFAOYSA-N': 'Amines',
#  'InChIKey=DDRJAANPRJIHGJ-UHFFFAOYSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=FFDGPVCHZBVARC-UHFFFAOYSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=MTCFGRXMJLQNBG-REOHCLBHSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=ZBCBWPMODOFKDW-UHFFFAOYSA-N': 'Amines',
#  'InChIKey=WBWWGRHZICKQGZ-HZAMXZRMSA-N': 'Bile acids, alcohols and derivatives',
#  'InChIKey=IAOZJIPTCAWIRG-QWRGUYRKSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=OVRNDRQMDRJTHS-RTRLPJTCSA-N': 'Carbohydrates and carbohydrate conjugates',
#  'InChIKey=CDLVFVFTRQPQFU-UHFFFAOYSA-N': 'Fatty acids and conjugates',
#  'InChIKey=BKAYIFDRRZZKNF-VIFPVBQESA-N': 'Hybrid peptides',
#  'InChIKey=GGOZGYRTNQBSSA-UHFFFAOYSA-N': 'Hydropyridines',
#  'InChIKey=VEYYWZRYIYDQJM-ZETCQYMHSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=RUDATBOHQWOJDD-BSWAIDMHSA-N': 'Bile acids, alcohols and derivatives',
#  'InChIKey=YAPQBXQYLJRXSA-UHFFFAOYSA-N': 'Purines and purine derivatives',
#  'InChIKey=KMAKOBLIOCQGJP-UHFFFAOYSA-N': 'Indolecarboxylic acids and derivatives',
#  'InChIKey=RITKHVBHSGLULN-WHFBIAKZSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=YAADMLWHGMUGQL-VOTSOKGWSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=QZAYGJVTTNCVMB-UHFFFAOYSA-N': 'Tryptamines and derivatives',
#  'InChIKey=MKWKNSIESPFAQN-UHFFFAOYSA-N': 'Cyclohexylamines',
#  'InChIKey=XULZWQRXYTVUTE-ZETCQYMHSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=CJKONRHMUGBAQI-UHFFFAOYSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=HLERILKGMXJNBU-UHFFFAOYSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=CWLQUGTUXBXTLF-YFKPBYRVSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=OUYCCCASQSFEME-QMMMGPOBSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=GMSNIKWWOQHZGF-UHFFFAOYSA-N': 'Purines and purine derivatives',
#  'InChIKey=ZYVXHFWBYUDDBM-UHFFFAOYSA-N': 'Pyridinecarboxylic acids and derivatives',
#  'InChIKey=LRQKBLKVPFOOQJ-UHFFFAOYSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=POJWUDADGALRAB-UHFFFAOYSA-N': 'Imidazoles',
#  'InChIKey=ONJSZLXSECQROL-UHFFFAOYSA-N': 'Benzoic acids and derivatives',
#  'InChIKey=QUNWUDVFRNGTCO-UHFFFAOYSA-N': 'Purines and purine derivatives',
#  'InChIKey=DATAGRPVKZEWHA-YFKPBYRVSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=ALYNCZNDIQEVRV-UHFFFAOYSA-N': 'Benzoic acids and derivatives',
#  'InChIKey=PLIKAWJENQZMHA-UHFFFAOYSA-N': 'Aniline and substituted anilines',
#  'InChIKey=BHQCQFFYRZLCQQ-OELDTZBJSA-N': 'Bile acids, alcohols and derivatives',
#  'InChIKey=ODKSFYDXXFIFQN-BYPYZUCNSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=AGPKZVBTJJNPAG-WHFBIAKZSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=QAFBDRSXXHEXGB-UHFFFAOYSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=NYHBQMYGNKIUIF-UUOKFMHZSA-N': 'Purine nucleosides',
#  'InChIKey=JCMUOFQHZLPHQP-BQBZGAKWSA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=RYYVLZVUVIJVGH-UHFFFAOYSA-N': 'Purines and purine derivatives',
#  'InChIKey=XTFQIRIHLGODFV-NSHDSACASA-N': 'Amino acids, peptides, and analogues',
#  'InChIKey=VYFYYTLLBUKUHU-UHFFFAOYSA-N': 'Benzenediols',
#  'InChIKey=LOAUVZALPPNFOQ-UHFFFAOYSA-N': 'Quinoline carboxylic acids',
#  'InChIKey=YGPSJZOEDVAXAB-QMMMGPOBSA-N': 'Carbonyl compounds'}

# %%
print(len(smilelist))
# Out:
# 251
